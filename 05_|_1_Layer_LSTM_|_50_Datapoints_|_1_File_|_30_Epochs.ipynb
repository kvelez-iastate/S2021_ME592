# %% [markdown]
# <a href="https://colab.research.google.com/github/kvelez-iastate/S2021_ME592/blob/project/05_%7C_1_Layer_LSTM_%7C_50_Datapoints_%7C_1_File_%7C_30_Epochs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Input

# %%
import os, sys
from google.colab import drive
drive.mount('/content/mnt')
nb_path = '/content/notebooks'
os.symlink('/content/mnt/My Drive/Colab Notebooks/ME592/Project', nb_path)
sys.path.insert(0, nb_path)
# Out:
# Mounted at /content/mnt

# %%
#%%

import sys
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib import cm
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable

import re
from sklearn.preprocessing import PolynomialFeatures
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold

# %%
#%%

path = r'/content/mnt/My Drive/Colab Notebooks/ME592/Project/NASA_TurboData/CMaps'
# path = r'C:\Users\ks07142\OneDrive-Deere&Co\OneDrive - Deere & Co\Graduate School\Spring2021_ME592\Project\NASA_TurboData\CMaps'

# loop through sub-directories and make a list of the paths to all data files
file_paths = []
for root, dirs, files in os.walk(path, topdown = True):
   for name in files:
      file_paths.append(os.path.join(root, name))


# Group Test data
test_data = []
for i in range(len(file_paths)):
  if 'test' in file_paths[i]:
    test_data.append(file_paths[i])
test_data = sorted(test_data)

# Group Train data
train_data = []
for i in range(len(file_paths)):
  if 'train' in file_paths[i]:
    train_data.append(file_paths[i])
train_data = sorted(train_data)

# Group Remaining Useful Life (RUL) data
rul_data = []
for i in range(len(file_paths)):
  if 'RUL' in file_paths[i]:
    rul_data.append(file_paths[i])
rul_data = sorted(rul_data)

# initialize normalization scale factors
input_scale = preprocessing.MinMaxScaler()
rul_scale = preprocessing.MinMaxScaler()

# initialize training lists
traindata_list = []
alltrainunitdata_list = []
alltrainunitdata_scaled_list = []
trainfailurecycle_list = []
trainingunit_list = []

files = 1

# run through each of the 4 training files
for i in range(files):
    
    # read in training data, one file at a time
    train = pd.read_csv(train_data[i],delimiter=' ',header=None)
    
    # initialize starting index for each unit collection
    startindex = 0
    
    # initialize list of unit data, this will seperate out each file into a 
    # seperate entry in a list
    unitdata_list = []
    
    # run through an individual training file to pull out groups of unit data
    for k in range(len(train)-1):
        
        # check the unit number of the next line, if they are different then 
        # this k value represents the end of a grouping of units
        if train.iloc[k,0] != train.iloc[k+1,0]:
            # the last index in the unit group
            endindex = k
            
            # all of the data in the unit group, as defined by the start and
            # end index values
            unitdata = train.iloc[startindex:endindex,:]
            # drop columns with NA values
            unitdata.dropna(axis=1,how='all',inplace=True)
            # add unit number to list before dropping
            trainingunit_list.append(unitdata.iloc[0,0])  
            # drop unit number as it isn't relevant to predictions
            unitdata = unitdata.iloc[:,1:]
            # drop uncorrelated columns
            unitdata.drop(unitdata.columns[[3,4,8,13,19,21,22]],axis=1,inplace=True)

            # scale values
            # unitdata_scaled = input_scale.fit_transform(unitdata)
            unitdata_cycles = unitdata.iloc[:,0].to_numpy()
            unitdata_scaled = input_scale.fit_transform(unitdata.iloc[:,1:])
            unitdata_scaled = np.column_stack((unitdata_cycles,unitdata_scaled))

            # in the training data, we assume it failed during the last cycle
            failurecycle = train.iloc[endindex,1]
            
            # update the starting index to the next unit group
            startindex = endindex + 1
            
            # append to lists
            trainfailurecycle_list.append(failurecycle)
            unitdata_list.append(unitdata)
            alltrainunitdata_list.append(unitdata)
            alltrainunitdata_scaled_list.append(unitdata_scaled)

        elif k == len(train)-2:
            # the last index in the unit group
            endindex = k
            
            # all of the data in the unit group, as defined by the start and
            # end index values
            unitdata = train.iloc[startindex:endindex,:]
            # drop columns with NA values
            unitdata.dropna(axis=1,how='all',inplace=True)
            # add unit number to list before dropping
            trainingunit_list.append(unitdata.iloc[0,0])
            # drop unit number as it isn't relevant to predictions
            unitdata = unitdata.iloc[:,1:]
            # drop uncorrelated columns
            unitdata.drop(unitdata.columns[[3,4,8,13,19,21,22]],axis=1,inplace=True)
            
            # scale values
            unitdata_cycles = unitdata.iloc[:,0].to_numpy()
            unitdata_scaled = input_scale.fit_transform(unitdata.iloc[:,1:])
            unitdata_scaled = np.column_stack((unitdata_cycles,unitdata_scaled))
            # in the training data, we assume it failed during the last cycle
            failurecycle = train.iloc[endindex,1]
            
            # update the starting index to the next unit group
            startindex = endindex + 1
            
            # append to lists
            trainfailurecycle_list.append(failurecycle)
            unitdata_list.append(unitdata)
            alltrainunitdata_list.append(unitdata)
            alltrainunitdata_scaled_list.append(unitdata_scaled)
            
            
    # append to list where each item is for a different file
    traindata_list.append(unitdata_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
trainingunit_np = np.array(trainingunit_list)
trainfailurecycle_np = np.array(trainfailurecycle_list)

plt.figure()
plt.scatter(trainingunit_np,trainfailurecycle_np)
# plt.scatter(unit_np,rul_np)
plt.ylabel('Total Cycles [cycles]')
plt.xlabel('Unit Number')
plt.title('Training Set Failures')
# plt.legend(('Prediction','Actual'))
# Out:
# Text(0.5, 1.0, 'Training Set Failures')

# %% [markdown]
# ## Model Training

# %%
#%% 
# sort into grouping of data with specified number of rows

datapoints = 50

groupedtrainData_list = []
removeindex = []

for i in range(len(alltrainunitdata_scaled_list)):
    if len(alltrainunitdata_scaled_list[i]) < datapoints:
        print(i)
        removeindex.append(i)

for k in range(len(removeindex)):
    removerow = removeindex[len(removeindex)-(k+1)]
    print(removeindex[len(removeindex)-(k+1)]) 
    del alltrainunitdata_scaled_list[removerow]
    del trainfailurecycle_list[removerow]

for j in range(len(alltrainunitdata_scaled_list)):
    # pull out a single dataset from the training data
    dataset = alltrainunitdata_scaled_list[j]
    # pull out the number of cycles for failure of that training dataset
    failurecycle = trainfailurecycle_list[j]
    
    # for each set of trainin data, group the data into datapoint number of rows
    # and attach the failure cycle to end
    for i in range(len(dataset)-datapoints+1):
        # RUL calculation
        RULentry = failurecycle - (i+datapoints)
        # select number of datapoints from training data
        groupedDataset = dataset[i:(i+datapoints),:]
        # make a list of the grouped data and the failures to cycle it should predict
        groupedData_entry = [groupedDataset,RULentry]
        # put all the data into a list
        groupedtrainData_list.append(groupedData_entry)

# %% [markdown]
# ### 100 LSTM, Linear

# %%
#%%

# neural network parameters
learning_rate = 0.001
hiddenlayers = 100
n_folds = 5

class MLModel(nn.Module):
    def __init__(self, input_size=18, hidden_layer_size=hiddenlayers, output_size=1):
        super().__init__()
        self.hidden_layer_size = hidden_layer_size

        self.lstm = nn.LSTM(input_size, hidden_layer_size)

        self.linear = nn.Linear(hidden_layer_size, output_size)

        self.hidden_cell = (torch.zeros(1,1,self.hidden_layer_size),
                            torch.zeros(1,1,self.hidden_layer_size))

    def forward(self, input_seq):
        lstm_out, self.hidden_cell = self.lstm(input_seq.view(len(input_seq) ,1, -1), self.hidden_cell)
        predictions = self.linear(lstm_out.view(len(input_seq), -1))
        return predictions[-1]

# %% [markdown]
# ### epochs

# %%
#%%

model = MLModel()
model = model.cuda()
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
k_fold = KFold(n_splits = n_folds, shuffle=False)

# covnert list to np array
groupedtrainData_np = np.array(groupedtrainData_list)

# Collect kfold loss to plot later
kfold_singleloss_list = []

num_epochs = 30

for epoch in range(num_epochs):
    trainfold = groupedtrainData_np
    traininput = trainfold[:,0]
    trainoutput = trainfold[:,1]
    
    singleloss_list = []

    for k in range(len(trainfold)):
        traininput_tensor = torch.tensor(traininput[k]).float()
        trainoutput_tensor = torch.tensor(trainoutput[k]).float()

        traininput_tensor = traininput_tensor
        trainoutput_tensor = trainoutput_tensor
        
        foldloss = 0
        optimizer.zero_grad()
        model.hidden_cell = (torch.zeros(1, 1, model.hidden_layer_size).cuda(),
                      torch.zeros(1, 1, model.hidden_layer_size).cuda())
        
        y_pred = model(traininput_tensor.cuda())
        single_loss = loss_function(y_pred, trainoutput_tensor.cuda())
        single_loss.backward()
        optimizer.step()
        
        singleloss_list.append(single_loss.detach().cpu().numpy())

        if k % 5000 == 0:
            text1 = 'Step: {} of {}, Predicted value: {}, Actual Value: {}'.format(k, len(trainfold), y_pred.detach().cpu().numpy(),trainoutput_tensor)
            print(text1)
            text = 'Loss is {}'.format(single_loss)
            print(text)
            
    kfold_singleloss_list.append(singleloss_list)
    
    text2 = 'Epoch {} of {} error is {}'.format(epoch,num_epochs,sum(kfold_singleloss_list[epoch])/len(kfold_singleloss_list[epoch]))
    print('-----------')
    print(text2)
    print('-----------')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:528: UserWarning: Using a target size (torch.Size([])) that is different to the input size (torch.Size([1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Step: 0 of 15630, Predicted value: [-0.3591597], Actual Value: 142.0
# Loss is 20266.130859375
# Step: 5000 of 15630, Predicted value: [106.36933], Actual Value: 107.0
# Loss is 0.3977429270744324
# Step: 10000 of 15630, Predicted value: [87.94967], Actual Value: 82.0
# Loss is 35.3985595703125
# Step: 15000 of 15630, Predicted value: [87.09851], Actual Value: 88.0
# Loss is 0.8126828670501709
# -----------
# Epoch 0 of 30 error is 2279.7603551277252
# -----------
# Step: 0 of 15630, Predicted value: [109.21608], Actual Value: 142.0
# Loss is 1074.785400390625
# Step: 5000 of 15630, Predicted value: [106.2274], Actual Value: 107.0
# Loss is 0.5969080924987793
# Step: 10000 of 15630, Predicted value: [82.4183], Actual Value: 82.0
# Loss is 0.17497222125530243
# Step: 15000 of 15630, Predicted value: [89.676704], Actual Value: 88.0
# Loss is 2.81133770942688
# -----------
# Epoch 1 of 30 error is 1516.9365345824394
# -----------
# Step: 0 of 15630, Predicted value: [130.94514], Actual Value: 142.0
# Loss is 122.20982360839844
# Step: 5000 of 15630, Predicted value: [108.539825], Actual Value: 107.0
# Loss is 2.3710622787475586
# Step: 10000 of 15630, Predicted value: [91.438194], Actual Value: 82.0
# Loss is 89.07951354980469
# Step: 15000 of 15630, Predicted value: [95.28679], Actual Value: 88.0
# Loss is 53.097293853759766
# -----------
# Epoch 2 of 30 error is 1543.3161238054001
# -----------
# Step: 0 of 15630, Predicted value: [132.19604], Actual Value: 142.0
# Loss is 96.11753845214844
# Step: 5000 of 15630, Predicted value: [106.53127], Actual Value: 107.0
# Loss is 0.21970510482788086
# Step: 10000 of 15630, Predicted value: [62.657017], Actual Value: 82.0
# Loss is 374.1510009765625
# Step: 15000 of 15630, Predicted value: [94.36237], Actual Value: 88.0
# Loss is 40.479793548583984
# -----------
# Epoch 3 of 30 error is 1540.302308123178
# -----------
# Step: 0 of 15630, Predicted value: [120.97161], Actual Value: 142.0
# Loss is 442.1931457519531
# Step: 5000 of 15630, Predicted value: [111.091034], Actual Value: 107.0
# Loss is 16.73655891418457
# Step: 10000 of 15630, Predicted value: [93.21969], Actual Value: 82.0
# Loss is 125.88140869140625
# Step: 15000 of 15630, Predicted value: [92.40238], Actual Value: 88.0
# Loss is 19.380966186523438
# -----------
# Epoch 4 of 30 error is 1349.4375972442429
# -----------
# Step: 0 of 15630, Predicted value: [124.559685], Actual Value: 142.0
# Loss is 304.1645812988281
# Step: 5000 of 15630, Predicted value: [104.960075], Actual Value: 107.0
# Loss is 4.161292552947998
# Step: 10000 of 15630, Predicted value: [53.582085], Actual Value: 82.0
# Loss is 807.5779418945312
# Step: 15000 of 15630, Predicted value: [92.42901], Actual Value: 88.0
# Loss is 19.61611557006836
# -----------
# Epoch 5 of 30 error is 1250.6640880469772
# -----------
# Step: 0 of 15630, Predicted value: [121.93454], Actual Value: 142.0
# Loss is 402.6226806640625
# Step: 5000 of 15630, Predicted value: [115.690414], Actual Value: 107.0
# Loss is 75.52330017089844
# Step: 10000 of 15630, Predicted value: [79.86373], Actual Value: 82.0
# Loss is 4.563643455505371
# Step: 15000 of 15630, Predicted value: [99.29612], Actual Value: 88.0
# Loss is 127.6023178100586
# -----------
# Epoch 6 of 30 error is 1224.7612821795701
# -----------
# Step: 0 of 15630, Predicted value: [119.205185], Actual Value: 142.0
# Loss is 519.6035766601562
# Step: 5000 of 15630, Predicted value: [114.77488], Actual Value: 107.0
# Loss is 60.44874954223633
# Step: 10000 of 15630, Predicted value: [96.71881], Actual Value: 82.0
# Loss is 216.64340209960938
# Step: 15000 of 15630, Predicted value: [91.998726], Actual Value: 88.0
# Loss is 15.989809036254883
# -----------
# Epoch 7 of 30 error is 1254.5729613482922
# -----------
# Step: 0 of 15630, Predicted value: [103.53996], Actual Value: 142.0
# Loss is 1479.1744384765625
# Step: 5000 of 15630, Predicted value: [113.41983], Actual Value: 107.0
# Loss is 41.2142219543457
# Step: 10000 of 15630, Predicted value: [92.946236], Actual Value: 82.0
# Loss is 119.82007598876953
# Step: 15000 of 15630, Predicted value: [91.18444], Actual Value: 88.0
# Loss is 10.14066219329834
# -----------
# Epoch 8 of 30 error is 1361.9146793564498
# -----------
# Step: 0 of 15630, Predicted value: [120.384926], Actual Value: 142.0
# Loss is 467.21142578125
# Step: 5000 of 15630, Predicted value: [113.21126], Actual Value: 107.0
# Loss is 38.5797233581543
# Step: 10000 of 15630, Predicted value: [84.6079], Actual Value: 82.0
# Loss is 6.8011555671691895
# Step: 15000 of 15630, Predicted value: [105.13961], Actual Value: 88.0
# Loss is 293.7662353515625
# -----------
# Epoch 9 of 30 error is 1235.0866080874027
# -----------
# Step: 0 of 15630, Predicted value: [129.67038], Actual Value: 142.0
# Loss is 152.01953125
# Step: 5000 of 15630, Predicted value: [109.44737], Actual Value: 107.0
# Loss is 5.989631652832031
# Step: 10000 of 15630, Predicted value: [89.22577], Actual Value: 82.0
# Loss is 52.21173858642578
# Step: 15000 of 15630, Predicted value: [88.892525], Actual Value: 88.0
# Loss is 0.7966004014015198
# -----------
# Epoch 10 of 30 error is 1201.457058363713
# -----------
# Step: 0 of 15630, Predicted value: [129.95767], Actual Value: 142.0
# Loss is 145.0176544189453
# Step: 5000 of 15630, Predicted value: [116.81111], Actual Value: 107.0
# Loss is 96.2579116821289
# Step: 10000 of 15630, Predicted value: [82.26223], Actual Value: 82.0
# Loss is 0.06876453012228012
# Step: 15000 of 15630, Predicted value: [90.85573], Actual Value: 88.0
# Loss is 8.155182838439941
# -----------
# Epoch 11 of 30 error is 1124.7557108233416
# -----------
# Step: 0 of 15630, Predicted value: [136.2184], Actual Value: 142.0
# Loss is 33.426910400390625
# Step: 5000 of 15630, Predicted value: [104.969376], Actual Value: 107.0
# Loss is 4.1234354972839355
# Step: 10000 of 15630, Predicted value: [81.71578], Actual Value: 82.0
# Loss is 0.0807797759771347
# Step: 15000 of 15630, Predicted value: [96.088875], Actual Value: 88.0
# Loss is 65.42989349365234
# -----------
# Epoch 12 of 30 error is 1118.3826437263915
# -----------
# Step: 0 of 15630, Predicted value: [130.78902], Actual Value: 142.0
# Loss is 125.68614959716797
# Step: 5000 of 15630, Predicted value: [122.88752], Actual Value: 107.0
# Loss is 252.4132843017578
# Step: 10000 of 15630, Predicted value: [83.60828], Actual Value: 82.0
# Loss is 2.586552858352661
# Step: 15000 of 15630, Predicted value: [92.87095], Actual Value: 88.0
# Loss is 23.72614288330078
# -----------
# Epoch 13 of 30 error is 988.55936285297
# -----------
# Step: 0 of 15630, Predicted value: [139.33275], Actual Value: 142.0
# Loss is 7.114231109619141
# Step: 5000 of 15630, Predicted value: [113.5629], Actual Value: 107.0
# Loss is 43.07161331176758
# Step: 10000 of 15630, Predicted value: [10.990689], Actual Value: 82.0
# Loss is 5042.32177734375
# Step: 15000 of 15630, Predicted value: [89.004295], Actual Value: 88.0
# Loss is 1.0086091756820679
# -----------
# Epoch 14 of 30 error is 1070.709444554771
# -----------
# Step: 0 of 15630, Predicted value: [102.17651], Actual Value: 142.0
# Loss is 1585.9100341796875
# Step: 5000 of 15630, Predicted value: [116.59279], Actual Value: 107.0
# Loss is 92.02159118652344
# Step: 10000 of 15630, Predicted value: [83.96975], Actual Value: 82.0
# Loss is 3.879912853240967
# Step: 15000 of 15630, Predicted value: [82.28354], Actual Value: 88.0
# Loss is 32.67792892456055
# -----------
# Epoch 15 of 30 error is 1117.770260162961
# -----------
# Step: 0 of 15630, Predicted value: [115.38468], Actual Value: 142.0
# Loss is 708.3751831054688
# Step: 5000 of 15630, Predicted value: [119.44021], Actual Value: 107.0
# Loss is 154.7587890625
# Step: 10000 of 15630, Predicted value: [88.00528], Actual Value: 82.0
# Loss is 36.06338119506836
# Step: 15000 of 15630, Predicted value: [91.244705], Actual Value: 88.0
# Loss is 10.528111457824707
# -----------
# Epoch 16 of 30 error is 1006.8035939137134
# -----------
# Step: 0 of 15630, Predicted value: [135.58499], Actual Value: 142.0
# Loss is 41.15233612060547
# Step: 5000 of 15630, Predicted value: [123.61093], Actual Value: 107.0
# Loss is 275.92303466796875
# Step: 10000 of 15630, Predicted value: [86.83115], Actual Value: 82.0
# Loss is 23.33997344970703
# Step: 15000 of 15630, Predicted value: [89.646835], Actual Value: 88.0
# Loss is 2.712066650390625
# -----------
# Epoch 17 of 30 error is 1059.9954487436169
# -----------
# Step: 0 of 15630, Predicted value: [139.4385], Actual Value: 142.0
# Loss is 6.561245918273926
# Step: 5000 of 15630, Predicted value: [122.79844], Actual Value: 107.0
# Loss is 249.59068298339844
# Step: 10000 of 15630, Predicted value: [81.240875], Actual Value: 82.0
# Loss is 0.5762704014778137
# Step: 15000 of 15630, Predicted value: [90.27065], Actual Value: 88.0
# Loss is 5.155864238739014
# -----------
# Epoch 18 of 30 error is 1022.132313045386
# -----------
# Step: 0 of 15630, Predicted value: [136.01648], Actual Value: 142.0
# Loss is 35.80251693725586
# Step: 5000 of 15630, Predicted value: [118.715645], Actual Value: 107.0
# Loss is 137.25633239746094
# Step: 10000 of 15630, Predicted value: [83.15485], Actual Value: 82.0
# Loss is 1.3336697816848755
# Step: 15000 of 15630, Predicted value: [88.71303], Actual Value: 88.0
# Loss is 0.5084088444709778
# -----------
# Epoch 19 of 30 error is 1005.4024094392703
# -----------
# Step: 0 of 15630, Predicted value: [135.0631], Actual Value: 142.0
# Loss is 48.12065124511719
# Step: 5000 of 15630, Predicted value: [120.02183], Actual Value: 107.0
# Loss is 169.5679931640625
# Step: 10000 of 15630, Predicted value: [88.300385], Actual Value: 82.0
# Loss is 39.69484329223633
# Step: 15000 of 15630, Predicted value: [95.44307], Actual Value: 88.0
# Loss is 55.39928436279297
# -----------
# Epoch 20 of 30 error is 1164.504821053512
# -----------
# Step: 0 of 15630, Predicted value: [147.88194], Actual Value: 142.0
# Loss is 34.597251892089844
# Step: 5000 of 15630, Predicted value: [110.375015], Actual Value: 107.0
# Loss is 11.390727996826172
# Step: 10000 of 15630, Predicted value: [83.90708], Actual Value: 82.0
# Loss is 3.63696026802063
# Step: 15000 of 15630, Predicted value: [92.002075], Actual Value: 88.0
# Loss is 16.016605377197266
# -----------
# Epoch 21 of 30 error is 1103.8085242188122
# -----------
# Step: 0 of 15630, Predicted value: [127.68826], Actual Value: 142.0
# Loss is 204.82582092285156
# Step: 5000 of 15630, Predicted value: [121.20565], Actual Value: 107.0
# Loss is 201.80050659179688
# Step: 10000 of 15630, Predicted value: [84.99058], Actual Value: 82.0
# Loss is 8.943554878234863
# Step: 15000 of 15630, Predicted value: [97.92988], Actual Value: 88.0
# Loss is 98.60247802734375
# -----------
# Epoch 22 of 30 error is 1097.1934480986617
# -----------
# Step: 0 of 15630, Predicted value: [136.38577], Actual Value: 142.0
# Loss is 31.519548416137695
# Step: 5000 of 15630, Predicted value: [119.84536], Actual Value: 107.0
# Loss is 165.00326538085938
# Step: 10000 of 15630, Predicted value: [82.70037], Actual Value: 82.0
# Loss is 0.490519255399704
# Step: 15000 of 15630, Predicted value: [93.244354], Actual Value: 88.0
# Loss is 27.503252029418945
# -----------
# Epoch 23 of 30 error is 832.5577884405227
# -----------
# Step: 0 of 15630, Predicted value: [119.48818], Actual Value: 142.0
# Loss is 506.7819519042969
# Step: 5000 of 15630, Predicted value: [111.868965], Actual Value: 107.0
# Loss is 23.70682144165039
# Step: 10000 of 15630, Predicted value: [91.64438], Actual Value: 82.0
# Loss is 93.0140380859375
# Step: 15000 of 15630, Predicted value: [92.283264], Actual Value: 88.0
# Loss is 18.346351623535156
# -----------
# Epoch 24 of 30 error is 884.5942023583144
# -----------
# Step: 0 of 15630, Predicted value: [137.92427], Actual Value: 142.0
# Loss is 16.611570358276367
# Step: 5000 of 15630, Predicted value: [120.45421], Actual Value: 107.0
# Loss is 181.01571655273438
# Step: 10000 of 15630, Predicted value: [85.39529], Actual Value: 82.0
# Loss is 11.527971267700195
# Step: 15000 of 15630, Predicted value: [82.6498], Actual Value: 88.0
# Loss is 28.62460708618164
# -----------
# Epoch 25 of 30 error is 920.887929028202
# -----------
# Step: 0 of 15630, Predicted value: [143.10365], Actual Value: 142.0
# Loss is 1.2180498838424683
# Step: 5000 of 15630, Predicted value: [110.281136], Actual Value: 107.0
# Loss is 10.765851020812988
# Step: 10000 of 15630, Predicted value: [81.55713], Actual Value: 82.0
# Loss is 0.1961348056793213
# Step: 15000 of 15630, Predicted value: [92.90706], Actual Value: 88.0
# Loss is 24.079225540161133
# -----------
# Epoch 26 of 30 error is 907.8990410924217
# -----------
# Step: 0 of 15630, Predicted value: [139.16888], Actual Value: 142.0
# Loss is 8.015215873718262
# Step: 5000 of 15630, Predicted value: [116.9405], Actual Value: 107.0
# Loss is 98.81350708007812
# Step: 10000 of 15630, Predicted value: [85.378845], Actual Value: 82.0
# Loss is 11.416595458984375
# Step: 15000 of 15630, Predicted value: [90.85262], Actual Value: 88.0
# Loss is 8.137457847595215
# -----------
# Epoch 27 of 30 error is 954.1280737191308
# -----------
# Step: 0 of 15630, Predicted value: [141.43762], Actual Value: 142.0
# Loss is 0.3162689208984375
# Step: 5000 of 15630, Predicted value: [123.29725], Actual Value: 107.0
# Loss is 265.6003112792969
# Step: 10000 of 15630, Predicted value: [81.73559], Actual Value: 82.0
# Loss is 0.06991367042064667
# Step: 15000 of 15630, Predicted value: [93.68028], Actual Value: 88.0
# Loss is 32.26560974121094
# -----------
# Epoch 28 of 30 error is 936.7942155067984
# -----------
# Step: 0 of 15630, Predicted value: [129.84259], Actual Value: 142.0
# Loss is 147.8026123046875
# Step: 5000 of 15630, Predicted value: [116.689415], Actual Value: 107.0
# Loss is 93.884765625
# Step: 10000 of 15630, Predicted value: [86.90545], Actual Value: 82.0
# Loss is 24.06342887878418
# Step: 15000 of 15630, Predicted value: [94.4711], Actual Value: 88.0
# Loss is 41.8751335144043
# -----------
# Epoch 29 of 30 error is 937.8079508154345
# -----------

# %%
epocherror = []

for i in range(num_epochs):
  epocherror.append(sum(kfold_singleloss_list[i])/len(kfold_singleloss_list[i]))

x = range(num_epochs)
plt.plot(x,epocherror)

# %% [markdown]
# ## Test

# %%
# initialize testing lists
testdata_list = []
alltestunitdata_list = []
alltestunitdata_scaled_list = []
testfailurecycle_list = []
unit_list = []
rul_list = []

# run through each of the 4 testing files
for i in range(files):
    
    # read in testing data, one file at a time
    test = pd.read_csv(test_data[i],delimiter=' ',header=None)
    rul = pd.read_csv(rul_data[i],delimiter=' ',header=None)
    
    # drop NA in RUL data
    rul.dropna(axis=1,how='all',inplace=True)
    
    # initialize starting index for each unit collection
    startindex = 0
    
    # initialize list of unit data, this will seperate out each file into a 
    # seperate entry in a list
    unitdata_list = []
    
    unitnumber = 0
    
    # run through an individual testing file to pull out groups of unit data
    for k in range(len(test)-1):
        
        # check the unit number of the next line, if they are different then 
        # this k value represents the end of a grouping of units
        if test.iloc[k,0] != test.iloc[k+1,0]:
            # the last index in the unit group
            endindex = k
            
            # all of the data in the unit group, as defined by the start and
            # end index values
            unitdata = test.iloc[startindex:endindex,:]
            # drop columns with NA values
            unitdata.dropna(axis=1,how='all',inplace=True)
            # add unit number to list before dropping
            unit_list.append(unitdata.iloc[0,0])            
            # drop unit number as it isn't relevant to predictions
            unitdata = unitdata.iloc[:,1:]
            # drop uncorrelated columns
            unitdata.drop(unitdata.columns[[3,4,8,13,19,21,22]],axis=1,inplace=True)

            # scale values
            unitdata_cycles = unitdata.iloc[:,0].to_numpy()
            unitdata_scaled = input_scale.fit_transform(unitdata.iloc[:,1:])
            unitdata_scaled = np.column_stack((unitdata_cycles,unitdata_scaled))
            
            # in the testing data, we assume it failed during the last cycle
            failurecycle = rul.iloc[unitnumber] + unitdata_cycles[-1]
            rul_list.append(rul.iloc[unitnumber].to_numpy())
            
            # update the starting index to the next unit group
            startindex = endindex + 1
            
            # append to lists
            testfailurecycle_list.append(failurecycle.values)
            unitdata_list.append(unitdata)
            alltestunitdata_list.append(unitdata)
            alltestunitdata_scaled_list.append(unitdata_scaled)
            
            unitnumber += 1
            
        # collecting the last unit of the dataset    
        elif k == len(test)-2:
            # the last index in the unit group
            endindex = k
            
            # all of the data in the unit group, as defined by the start and
            # end index values
            unitdata = test.iloc[startindex:endindex,:]
            # drop columns with NA values
            unitdata.dropna(axis=1,how='all',inplace=True)
            # add unit number to list before dropping
            unit_list.append(unitdata.iloc[0,0]) 
            # drop unit number as it isn't relevant to predictions
            unitdata = unitdata.iloc[:,1:]
            # drop uncorrelated columns
            unitdata.drop(unitdata.columns[[3,4,8,13,19,21,22]],axis=1,inplace=True)
            
            # scale values
            unitdata_cycles = unitdata.iloc[:,0].to_numpy()
            unitdata_scaled = input_scale.fit_transform(unitdata.iloc[:,1:])
            unitdata_scaled = np.column_stack((unitdata_cycles,unitdata_scaled))
            
            # in the testing data, we assume it failed during the last cycle
            failurecycle = rul.iloc[unitnumber] + unitdata_cycles[-1]
            rul_list.append(rul.iloc[unitnumber].to_numpy())
            
            # update the starting index to the next unit group
            startindex = endindex + 1
            
            # append to lists
            testfailurecycle_list.append(failurecycle.values)
            unitdata_list.append(unitdata)
            alltestunitdata_list.append(unitdata)
            alltestunitdata_scaled_list.append(unitdata_scaled)
            
            unitnumber += 1
            
            
            
    # append to list where each item is for a different file
    testdata_list.append(unitdata_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
datapoints = 50

groupedtestData_list = []
test_predict_list = []
predictions_list = []
removeindex = []

for i in range(len(alltestunitdata_scaled_list)):
    if len(alltestunitdata_scaled_list[i]) < datapoints:
        print(i)
        removeindex.append(i)

for k in range(len(removeindex)):
    removerow = removeindex[len(removeindex)-(k+1)]
    del alltestunitdata_scaled_list[removerow]
    del testfailurecycle_list[removerow]
    del unit_list[removerow]
    del rul_list[removerow]

for j in range(len(alltestunitdata_scaled_list)):
    # pull out a single dataset from the training data
    dataset = alltestunitdata_scaled_list[j]
    # pull out the number of cycles for failure of that training dataset
    failurecycle = testfailurecycle_list[j]
    
    predictions = []
    # for each set of trainin data, group the data into datapoint number of rows
    # and attach the failure cycle to end
    for i in range(len(dataset)-datapoints+1):
        # RUL calculation
        RULentry = failurecycle - (i+datapoints)
        # select number of datapoints from training data
        groupedDataset = dataset[i:(i+datapoints),:]
        # make a list of the grouped data and the failures to cycle it should predict
        groupedData_entry = [groupedDataset,RULentry]
        # put all the data into a list
        groupedtestData_list.append(groupedData_entry)
        
        test_tensor = torch.tensor(groupedDataset).float()

        test_predict = model(test_tensor.cuda())

        predictions.append(test_predict.detach().cpu().numpy())
    
    test_singleprediction = predictions[-1]
    test_predict_list.append(test_singleprediction)
    predictions_list.append(predictions)

    # print('Prediction: {}, RUL: {}'.format(test_singleprediction,failurecycle))
# Out:
# 0
# 1
# 13
# 21
# 24
# 32
# 38
# 84

# %%
trainingunit_np = np.array(trainingunit_list)
trainfailurecycle_np = np.array(trainfailurecycle_list)
unit_np = np.array(unit_list)
testfailurecycle_np = np.array(testfailurecycle_list)

plt.figure()
plt.scatter(trainingunit_np,trainfailurecycle_np)
plt.scatter(unit_np,testfailurecycle_np)
plt.ylabel('Cycles at failure')
plt.xlabel('Unit Number')
plt.title('Training vs. Test Set Cyles at Failure')
plt.legend(('Training','Test'))

# %%
step_np = range(len(test_predict_list))
test_predict_np = np.array(test_predict_list)
testfailurecycle_np = np.array(testfailurecycle_list)
RUL_np = np.array(rul_list)

plt.figure()
plt.scatter(step_np,test_predict_np)
plt.scatter(step_np,RUL_np)
plt.ylabel('Remaining Useful Life [cycles]',size=14)
plt.xlabel('Steps',size=14)
plt.legend(('Prediction','Actual'))
plt.rcParams["figure.figsize"] = (10,6)

# %%
unit_np = np.array(unit_list)
test_predict_np = np.array(test_predict_list)
testfailurecycle_np = np.array(testfailurecycle_list)

plt.figure()
plt.scatter(unit_np,test_predict_np)
plt.scatter(unit_np,RUL_np)
plt.ylabel('Remaining Useful Life [cycles]',size=14)
plt.xlabel('Unit Number',size=14)
plt.legend(('Prediction','Actual'))
