# %% [markdown]
# <a href="https://colab.research.google.com/github/kvelez-iastate/S2021_ME592/blob/project/10_%7C_2_Layer_LSTM_%7C_50_Datapoints_%7C_1_File_%7C_10_Epochs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Input

# %%
import os, sys
from google.colab import drive
drive.mount('/content/mnt')
nb_path = '/content/notebooks'
os.symlink('/content/mnt/My Drive/Colab Notebooks/ME592/Project', nb_path)
sys.path.insert(0, nb_path)
# Out:
# Mounted at /content/mnt

# %%
#%%

import sys
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib import cm
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable

import re
from sklearn.preprocessing import PolynomialFeatures
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold

# %%
#%%

path = r'/content/mnt/My Drive/Colab Notebooks/ME592/Project/NASA_TurboData/CMaps'
# path = r'C:\Users\ks07142\OneDrive-Deere&Co\OneDrive - Deere & Co\Graduate School\Spring2021_ME592\Project\NASA_TurboData\CMaps'

# loop through sub-directories and make a list of the paths to all data files
file_paths = []
for root, dirs, files in os.walk(path, topdown = True):
   for name in files:
      file_paths.append(os.path.join(root, name))


# Group Test data
test_data = []
for i in range(len(file_paths)):
  if 'test' in file_paths[i]:
    test_data.append(file_paths[i])
test_data = sorted(test_data)

# Group Train data
train_data = []
for i in range(len(file_paths)):
  if 'train' in file_paths[i]:
    train_data.append(file_paths[i])
train_data = sorted(train_data)

# Group Remaining Useful Life (RUL) data
rul_data = []
for i in range(len(file_paths)):
  if 'RUL' in file_paths[i]:
    rul_data.append(file_paths[i])
rul_data = sorted(rul_data)

# initialize normalization scale factors
input_scale = preprocessing.MinMaxScaler()
rul_scale = preprocessing.MinMaxScaler()

# initialize training lists
traindata_list = []
alltrainunitdata_list = []
alltrainunitdata_scaled_list = []
trainfailurecycle_list = []
trainingunit_list = []

files = 1
# run through each of the 4 training files
for i in range(files):
    
    # read in training data, one file at a time
    train = pd.read_csv(train_data[i],delimiter=' ',header=None)
    
    # initialize starting index for each unit collection
    startindex = 0
    
    # initialize list of unit data, this will seperate out each file into a 
    # seperate entry in a list
    unitdata_list = []
    
    # run through an individual training file to pull out groups of unit data
    for k in range(len(train)-1):
        
        # check the unit number of the next line, if they are different then 
        # this k value represents the end of a grouping of units
        if train.iloc[k,0] != train.iloc[k+1,0]:
            # the last index in the unit group
            endindex = k
            
            # all of the data in the unit group, as defined by the start and
            # end index values
            unitdata = train.iloc[startindex:endindex,:]
            # drop columns with NA values
            unitdata.dropna(axis=1,how='all',inplace=True)
            # add unit number to list before dropping
            trainingunit_list.append(unitdata.iloc[0,0])  
            # drop unit number as it isn't relevant to predictions
            unitdata = unitdata.iloc[:,1:]
            # drop uncorrelated columns
            unitdata.drop(unitdata.columns[[3,4,8,13,19,21,22]],axis=1,inplace=True)

            # scale values
            # unitdata_scaled = input_scale.fit_transform(unitdata)
            unitdata_cycles = unitdata.iloc[:,0].to_numpy()
            unitdata_scaled = input_scale.fit_transform(unitdata.iloc[:,1:])
            unitdata_scaled = np.column_stack((unitdata_cycles,unitdata_scaled))

            # in the training data, we assume it failed during the last cycle
            failurecycle = train.iloc[endindex,1]
            
            # update the starting index to the next unit group
            startindex = endindex + 1
            
            # append to lists
            trainfailurecycle_list.append(failurecycle)
            unitdata_list.append(unitdata)
            alltrainunitdata_list.append(unitdata)
            alltrainunitdata_scaled_list.append(unitdata_scaled)

        elif k == len(train)-2:
            # the last index in the unit group
            endindex = k
            
            # all of the data in the unit group, as defined by the start and
            # end index values
            unitdata = train.iloc[startindex:endindex,:]
            # drop columns with NA values
            unitdata.dropna(axis=1,how='all',inplace=True)
            # add unit number to list before dropping
            trainingunit_list.append(unitdata.iloc[0,0])
            # drop unit number as it isn't relevant to predictions
            unitdata = unitdata.iloc[:,1:]
            # drop uncorrelated columns
            unitdata.drop(unitdata.columns[[3,4,8,13,19,21,22]],axis=1,inplace=True)
            
            # scale values
            unitdata_cycles = unitdata.iloc[:,0].to_numpy()
            unitdata_scaled = input_scale.fit_transform(unitdata.iloc[:,1:])
            unitdata_scaled = np.column_stack((unitdata_cycles,unitdata_scaled))
            # in the training data, we assume it failed during the last cycle
            failurecycle = train.iloc[endindex,1]
            
            # update the starting index to the next unit group
            startindex = endindex + 1
            
            # append to lists
            trainfailurecycle_list.append(failurecycle)
            unitdata_list.append(unitdata)
            alltrainunitdata_list.append(unitdata)
            alltrainunitdata_scaled_list.append(unitdata_scaled)
            
            
    # append to list where each item is for a different file
    traindata_list.append(unitdata_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
trainingunit_np = np.array(trainingunit_list)
trainfailurecycle_np = np.array(trainfailurecycle_list)

plt.figure()
plt.scatter(trainingunit_np,trainfailurecycle_np)
# plt.scatter(unit_np,rul_np)
plt.ylabel('Total Cycles [cycles]')
plt.xlabel('Unit Number')
plt.title('Training Set Failures')
# plt.legend(('Prediction','Actual'))
# Out:
# Text(0.5, 1.0, 'Training Set Failures')

# %% [markdown]
# ## Model Training

# %%
#%% 
# sort into grouping of data with specified number of rows

datapoints = 50

groupedtrainData_list = []
removeindex = []

for i in range(len(alltrainunitdata_scaled_list)):
    if len(alltrainunitdata_scaled_list[i]) < datapoints:
        print(i)
        removeindex.append(i)

for k in range(len(removeindex)):
    removerow = removeindex[len(removeindex)-(k+1)]
    print(removeindex[len(removeindex)-(k+1)]) 
    del alltrainunitdata_scaled_list[removerow]
    del trainfailurecycle_list[removerow]

for j in range(len(alltrainunitdata_scaled_list)):
    # pull out a single dataset from the training data
    dataset = alltrainunitdata_scaled_list[j]
    # pull out the number of cycles for failure of that training dataset
    failurecycle = trainfailurecycle_list[j]
    
    # for each set of trainin data, group the data into datapoint number of rows
    # and attach the failure cycle to end
    for i in range(len(dataset)-datapoints+1):
        # RUL calculation
        RULentry = failurecycle - (i+datapoints)
        # select number of datapoints from training data
        groupedDataset = dataset[i:(i+datapoints),:]
        # make a list of the grouped data and the failures to cycle it should predict
        groupedData_entry = [groupedDataset,RULentry]
        # put all the data into a list
        groupedtrainData_list.append(groupedData_entry)

# %%
#%%

# neural network parameters
learning_rate = 0.001
hiddenlayers = 100
n_folds = 5

class MLModel(nn.Module):
    def __init__(self, input_size=25, hidden_layer_size=hiddenlayers, output_size=1):
        super().__init__()
        self.hidden_layer_size = hidden_layer_size

        self.lstm = nn.LSTM(input_size, hidden_layer_size)

        self.linear = nn.Linear(hidden_layer_size, output_size)

        self.hidden_cell = (torch.zeros(1,1,self.hidden_layer_size),
                            torch.zeros(1,1,self.hidden_layer_size))

    def forward(self, input_seq):
        lstm_out, self.hidden_cell = self.lstm(input_seq.view(len(input_seq) ,1, -1), self.hidden_cell)
        predictions = self.linear(lstm_out.view(len(input_seq), -1))
        return predictions[-1]

# %% [markdown]
# ### 100 LSTM, 50 LSTM, Linear

# %%
#%%

# neural network parameters
learning_rate = 0.001
hiddenlayers1 = 100
hiddenlayers2 = 50
n_folds = 5

class MLModel(nn.Module):
    def __init__(self, input_size=18, hidden_layer_size1=hiddenlayers1, hidden_layer_size2=hiddenlayers2, output_size=1):
        super().__init__()
        self.hidden_layer_size1 = hidden_layer_size1

        self.hidden_layer_size2 = hidden_layer_size2

        self.lstm1 = nn.LSTM(input_size, hidden_layer_size1)

        self.lstm2 = nn.LSTM(hidden_layer_size1, hidden_layer_size2)

        self.linear = nn.Linear(hidden_layer_size2, output_size)

        self.hidden_cell1 = (torch.zeros(1,1,self.hidden_layer_size1),
                            torch.zeros(1,1,self.hidden_layer_size1))
        
        self.hidden_cell2 = (torch.zeros(1,1,self.hidden_layer_size2),
                            torch.zeros(1,1,self.hidden_layer_size2))

    def forward(self, input_seq):
        lstm_out1, self.hidden_cell1 = self.lstm1(input_seq.view(len(input_seq) ,1, -1), self.hidden_cell1)
        lstm_out2, self.hidden_cell2 = self.lstm2(lstm_out1, self.hidden_cell2)
        predictions = self.linear(lstm_out2.view(len(input_seq), -1))
        return predictions[-1]

# %% [markdown]
# ### epochs

# %%
#%%

model = MLModel()
model = model.cuda()
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
k_fold = KFold(n_splits = n_folds, shuffle=False)

# covnert list to np array
groupedtrainData_np = np.array(groupedtrainData_list)

# Collect kfold loss to plot later
kfold_singleloss_list = []

num_epochs = 10

for epoch in range(num_epochs):
    trainfold = groupedtrainData_np
    traininput = trainfold[:,0]
    trainoutput = trainfold[:,1]
    
    singleloss_list = []

    for k in range(len(trainfold)):
        traininput_tensor = torch.tensor(traininput[k]).float()
        trainoutput_tensor = torch.tensor(trainoutput[k]).float()

        traininput_tensor = traininput_tensor
        trainoutput_tensor = trainoutput_tensor
        
        foldloss = 0
        optimizer.zero_grad()
        model.hidden_cell1 = (torch.zeros(1, 1, model.hidden_layer_size1).cuda(),
                      torch.zeros(1, 1, model.hidden_layer_size1).cuda())
        model.hidden_cell2 = (torch.zeros(1, 1, model.hidden_layer_size2).cuda(),
                      torch.zeros(1, 1, model.hidden_layer_size2).cuda())
        
        y_pred = model(traininput_tensor.cuda())
        single_loss = loss_function(y_pred, trainoutput_tensor.cuda())
        single_loss.backward()
        optimizer.step()
        
        singleloss_list.append(single_loss.detach().cpu().numpy())

        if k % 1000 == 0:
            text1 = 'Step: {} of {}, Predicted value: {}, Actual Value: {}'.format(k, len(trainfold), y_pred.detach().cpu().numpy(),trainoutput_tensor)
            print(text1)
            text = 'Loss is {}'.format(single_loss)
            print(text)
            
    kfold_singleloss_list.append(singleloss_list)
    
    text2 = 'Epoch {} of {} error is {}'.format(epoch,num_epoch,sum(kfold_singleloss_list[epoch])/len(kfold_singleloss_list[epoch]))
    print('-----------')
    print(text2)
    print('-----------')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:528: UserWarning: Using a target size (torch.Size([])) that is different to the input size (torch.Size([1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Step: 0 of 15630, Predicted value: [0.06607639], Actual Value: 142.0
# Loss is 20145.240234375
# Step: 1000 of 15630, Predicted value: [37.380962], Actual Value: 4.0
# Loss is 1114.2886962890625
# Step: 2000 of 15630, Predicted value: [54.220562], Actual Value: 59.0
# Loss is 22.843027114868164
# Step: 3000 of 15630, Predicted value: [58.322662], Actual Value: 168.0
# Loss is 12029.1181640625
# Step: 4000 of 15630, Predicted value: [17.559265], Actual Value: 9.0
# Loss is 73.26101684570312
# Step: 5000 of 15630, Predicted value: [88.098724], Actual Value: 107.0
# Loss is 357.2582092285156
# Step: 6000 of 15630, Predicted value: [92.80517], Actual Value: 138.0
# Loss is 2042.5728759765625
# Step: 7000 of 15630, Predicted value: [99.165504], Actual Value: 96.0
# Loss is 10.020418167114258
# Step: 8000 of 15630, Predicted value: [82.959045], Actual Value: 87.0
# Loss is 16.329313278198242
# Step: 9000 of 15630, Predicted value: [74.85421], Actual Value: 77.0
# Loss is 4.604414939880371
# Step: 10000 of 15630, Predicted value: [77.82833], Actual Value: 82.0
# Loss is 17.402822494506836
# Step: 11000 of 15630, Predicted value: [105.21246], Actual Value: 114.0
# Loss is 77.2208023071289
# Step: 12000 of 15630, Predicted value: [5.1971674], Actual Value: 3.0
# Loss is 4.827544689178467
# Step: 13000 of 15630, Predicted value: [126.403885], Actual Value: 90.0
# Loss is 1325.2427978515625
# Step: 14000 of 15630, Predicted value: [127.102325], Actual Value: 256.0
# Loss is 16614.611328125
# Step: 15000 of 15630, Predicted value: [86.88171], Actual Value: 88.0
# Loss is 1.250580906867981
# -----------
# Epoch error is 2198.9750351537728
# -----------
# Step: 0 of 15630, Predicted value: [108.747345], Actual Value: 142.0
# Loss is 1105.739013671875
# Step: 1000 of 15630, Predicted value: [4.073612], Actual Value: 4.0
# Loss is 0.005418757908046246
# Step: 2000 of 15630, Predicted value: [47.375023], Actual Value: 59.0
# Loss is 135.1400909423828
# Step: 3000 of 15630, Predicted value: [104.02587], Actual Value: 168.0
# Loss is 4092.689208984375
# Step: 4000 of 15630, Predicted value: [9.6487465], Actual Value: 9.0
# Loss is 0.4208720028400421
# Step: 5000 of 15630, Predicted value: [124.6712], Actual Value: 107.0
# Loss is 312.27142333984375
# Step: 6000 of 15630, Predicted value: [121.35056], Actual Value: 138.0
# Loss is 277.2037658691406
# Step: 7000 of 15630, Predicted value: [97.22806], Actual Value: 96.0
# Loss is 1.508126139640808
# Step: 8000 of 15630, Predicted value: [85.81959], Actual Value: 87.0
# Loss is 1.3933731317520142
# Step: 9000 of 15630, Predicted value: [90.11137], Actual Value: 77.0
# Loss is 171.90792846679688
# Step: 10000 of 15630, Predicted value: [83.36408], Actual Value: 82.0
# Loss is 1.8607206344604492
# Step: 11000 of 15630, Predicted value: [114.77978], Actual Value: 114.0
# Loss is 0.6080529689788818
# Step: 12000 of 15630, Predicted value: [7.571822], Actual Value: 3.0
# Loss is 20.90155792236328
# Step: 13000 of 15630, Predicted value: [92.67994], Actual Value: 90.0
# Loss is 7.182074546813965
# Step: 14000 of 15630, Predicted value: [161.49792], Actual Value: 256.0
# Loss is 8930.642578125
# Step: 15000 of 15630, Predicted value: [88.70651], Actual Value: 88.0
# Loss is 0.4991598427295685
# -----------
# Epoch error is 949.5654212152797
# -----------
# Step: 0 of 15630, Predicted value: [131.3099], Actual Value: 142.0
# Loss is 114.27810668945312
# Step: 1000 of 15630, Predicted value: [6.2977276], Actual Value: 4.0
# Loss is 5.279551982879639
# Step: 2000 of 15630, Predicted value: [60.380253], Actual Value: 59.0
# Loss is 1.9050978422164917
# Step: 3000 of 15630, Predicted value: [119.69751], Actual Value: 168.0
# Loss is 2333.130615234375
# Step: 4000 of 15630, Predicted value: [11.375816], Actual Value: 9.0
# Loss is 5.644503116607666
# Step: 5000 of 15630, Predicted value: [102.01328], Actual Value: 107.0
# Loss is 24.86734962463379
# Step: 6000 of 15630, Predicted value: [149.36835], Actual Value: 138.0
# Loss is 129.23931884765625
# Step: 7000 of 15630, Predicted value: [94.21122], Actual Value: 96.0
# Loss is 3.199734687805176
# Step: 8000 of 15630, Predicted value: [84.07983], Actual Value: 87.0
# Loss is 8.527414321899414
# Step: 9000 of 15630, Predicted value: [103.16206], Actual Value: 77.0
# Loss is 684.4535522460938
# Step: 10000 of 15630, Predicted value: [83.42731], Actual Value: 82.0
# Loss is 2.037205696105957
# Step: 11000 of 15630, Predicted value: [116.234276], Actual Value: 114.0
# Loss is 4.991988658905029
# Step: 12000 of 15630, Predicted value: [6.7227015], Actual Value: 3.0
# Loss is 13.85850715637207
# Step: 13000 of 15630, Predicted value: [92.11213], Actual Value: 90.0
# Loss is 4.461089611053467
# Step: 14000 of 15630, Predicted value: [142.08339], Actual Value: 256.0
# Loss is 12976.994140625
# Step: 15000 of 15630, Predicted value: [90.1851], Actual Value: 88.0
# Loss is 4.7746477127075195
# -----------
# Epoch error is 887.0704884785813
# -----------
# Step: 0 of 15630, Predicted value: [101.58756], Actual Value: 142.0
# Loss is 1633.1650390625
# Step: 1000 of 15630, Predicted value: [4.73646], Actual Value: 4.0
# Loss is 0.5423736572265625
# Step: 2000 of 15630, Predicted value: [61.193817], Actual Value: 59.0
# Loss is 4.812833786010742
# Step: 3000 of 15630, Predicted value: [141.30193], Actual Value: 168.0
# Loss is 712.7871704101562
# Step: 4000 of 15630, Predicted value: [10.836121], Actual Value: 9.0
# Loss is 3.3713388442993164
# Step: 5000 of 15630, Predicted value: [121.22048], Actual Value: 107.0
# Loss is 202.22210693359375
# Step: 6000 of 15630, Predicted value: [150.81128], Actual Value: 138.0
# Loss is 164.12887573242188
# Step: 7000 of 15630, Predicted value: [96.21598], Actual Value: 96.0
# Loss is 0.04664758965373039
# Step: 8000 of 15630, Predicted value: [84.63992], Actual Value: 87.0
# Loss is 5.569962978363037
# Step: 9000 of 15630, Predicted value: [76.965], Actual Value: 77.0
# Loss is 0.001225256361067295
# Step: 10000 of 15630, Predicted value: [76.85478], Actual Value: 82.0
# Loss is 26.4732666015625
# Step: 11000 of 15630, Predicted value: [117.87041], Actual Value: 114.0
# Loss is 14.980051040649414
# Step: 12000 of 15630, Predicted value: [1.1882172], Actual Value: 3.0
# Loss is 3.2825570106506348
# Step: 13000 of 15630, Predicted value: [142.52145], Actual Value: 90.0
# Loss is 2758.503173828125
# Step: 14000 of 15630, Predicted value: [141.63194], Actual Value: 256.0
# Loss is 13080.052734375
# Step: 15000 of 15630, Predicted value: [88.59972], Actual Value: 88.0
# Loss is 0.35965949296951294
# -----------
# Epoch error is 814.6416895553898
# -----------
# Step: 0 of 15630, Predicted value: [125.92308], Actual Value: 142.0
# Loss is 258.46734619140625
# Step: 1000 of 15630, Predicted value: [8.063552], Actual Value: 4.0
# Loss is 16.512454986572266
# Step: 2000 of 15630, Predicted value: [58.19418], Actual Value: 59.0
# Loss is 0.649346649646759
# Step: 3000 of 15630, Predicted value: [148.11226], Actual Value: 168.0
# Loss is 395.5222473144531
# Step: 4000 of 15630, Predicted value: [10.446192], Actual Value: 9.0
# Loss is 2.091470718383789
# Step: 5000 of 15630, Predicted value: [92.16079], Actual Value: 107.0
# Loss is 220.20216369628906
# Step: 6000 of 15630, Predicted value: [147.03415], Actual Value: 138.0
# Loss is 81.61585235595703
# Step: 7000 of 15630, Predicted value: [95.357124], Actual Value: 96.0
# Loss is 0.4132891297340393
# Step: 8000 of 15630, Predicted value: [85.99991], Actual Value: 87.0
# Loss is 1.00018310546875
# Step: 9000 of 15630, Predicted value: [77.03775], Actual Value: 77.0
# Loss is 0.0014250809326767921
# Step: 10000 of 15630, Predicted value: [76.60191], Actual Value: 82.0
# Loss is 29.13933753967285
# Step: 11000 of 15630, Predicted value: [118.3957], Actual Value: 114.0
# Loss is 19.322166442871094
# Step: 12000 of 15630, Predicted value: [2.8879452], Actual Value: 3.0
# Loss is 0.012556283734738827
# Step: 13000 of 15630, Predicted value: [108.51104], Actual Value: 90.0
# Loss is 342.6585998535156
# Step: 14000 of 15630, Predicted value: [188.56566], Actual Value: 256.0
# Loss is 4547.390625
# Step: 15000 of 15630, Predicted value: [82.2227], Actual Value: 88.0
# Loss is 33.37717056274414
# -----------
# Epoch error is 601.0243946874856
# -----------
# Step: 0 of 15630, Predicted value: [128.0886], Actual Value: 142.0
# Loss is 193.52725219726562
# Step: 1000 of 15630, Predicted value: [0.1346507], Actual Value: 4.0
# Loss is 14.940925598144531
# Step: 2000 of 15630, Predicted value: [63.244854], Actual Value: 59.0
# Loss is 18.01878547668457
# Step: 3000 of 15630, Predicted value: [150.38911], Actual Value: 168.0
# Loss is 310.1432800292969
# Step: 4000 of 15630, Predicted value: [9.470287], Actual Value: 9.0
# Loss is 0.22117017209529877
# Step: 5000 of 15630, Predicted value: [107.45137], Actual Value: 107.0
# Loss is 0.2037350982427597
# Step: 6000 of 15630, Predicted value: [138.10776], Actual Value: 138.0
# Loss is 0.011611693538725376
# Step: 7000 of 15630, Predicted value: [94.65802], Actual Value: 96.0
# Loss is 1.800910234451294
# Step: 8000 of 15630, Predicted value: [86.080734], Actual Value: 87.0
# Loss is 0.8450495004653931
# Step: 9000 of 15630, Predicted value: [78.582756], Actual Value: 77.0
# Loss is 2.5051167011260986
# Step: 10000 of 15630, Predicted value: [91.72945], Actual Value: 82.0
# Loss is 94.66212463378906
# Step: 11000 of 15630, Predicted value: [109.88322], Actual Value: 114.0
# Loss is 16.94790267944336
# Step: 12000 of 15630, Predicted value: [4.1734815], Actual Value: 3.0
# Loss is 1.377058744430542
# Step: 13000 of 15630, Predicted value: [87.79326], Actual Value: 90.0
# Loss is 4.869707107543945
# Step: 14000 of 15630, Predicted value: [149.7998], Actual Value: 256.0
# Loss is 11278.4814453125
# Step: 15000 of 15630, Predicted value: [89.93318], Actual Value: 88.0
# Loss is 3.737191677093506
# -----------
# Epoch error is 696.9591420065158
# -----------
# Step: 0 of 15630, Predicted value: [147.18358], Actual Value: 142.0
# Loss is 26.86948585510254
# Step: 1000 of 15630, Predicted value: [4.1867185], Actual Value: 4.0
# Loss is 0.03486378490924835
# Step: 2000 of 15630, Predicted value: [57.077312], Actual Value: 59.0
# Loss is 3.6967272758483887
# Step: 3000 of 15630, Predicted value: [117.595795], Actual Value: 168.0
# Loss is 2540.583984375
# Step: 4000 of 15630, Predicted value: [7.873914], Actual Value: 9.0
# Loss is 1.2680702209472656
# Step: 5000 of 15630, Predicted value: [114.74521], Actual Value: 107.0
# Loss is 59.988258361816406
# Step: 6000 of 15630, Predicted value: [125.79558], Actual Value: 138.0
# Loss is 148.9479217529297
# Step: 7000 of 15630, Predicted value: [96.76181], Actual Value: 96.0
# Loss is 0.5803549289703369
# Step: 8000 of 15630, Predicted value: [85.32396], Actual Value: 87.0
# Loss is 2.809112310409546
# Step: 9000 of 15630, Predicted value: [75.93069], Actual Value: 77.0
# Loss is 1.1434303522109985
# Step: 10000 of 15630, Predicted value: [83.206184], Actual Value: 82.0
# Loss is 1.4548808336257935
# Step: 11000 of 15630, Predicted value: [125.48844], Actual Value: 114.0
# Loss is 131.98428344726562
# Step: 12000 of 15630, Predicted value: [4.6834383], Actual Value: 3.0
# Loss is 2.8339645862579346
# Step: 13000 of 15630, Predicted value: [82.59505], Actual Value: 90.0
# Loss is 54.83332824707031
# Step: 14000 of 15630, Predicted value: [158.88135], Actual Value: 256.0
# Loss is 9432.0322265625
# Step: 15000 of 15630, Predicted value: [89.98996], Actual Value: 88.0
# Loss is 3.95993971824646
# -----------
# Epoch error is 727.1347573197809
# -----------
# Step: 0 of 15630, Predicted value: [110.58881], Actual Value: 142.0
# Loss is 986.66259765625
# Step: 1000 of 15630, Predicted value: [8.527461], Actual Value: 4.0
# Loss is 20.49790382385254
# Step: 2000 of 15630, Predicted value: [62.83688], Actual Value: 59.0
# Loss is 14.721646308898926
# Step: 3000 of 15630, Predicted value: [122.64591], Actual Value: 168.0
# Loss is 2056.9931640625
# Step: 4000 of 15630, Predicted value: [11.06966], Actual Value: 9.0
# Loss is 4.283493518829346
# Step: 5000 of 15630, Predicted value: [113.91789], Actual Value: 107.0
# Loss is 47.857234954833984
# Step: 6000 of 15630, Predicted value: [138.8797], Actual Value: 138.0
# Loss is 0.7738716006278992
# Step: 7000 of 15630, Predicted value: [95.67612], Actual Value: 96.0
# Loss is 0.10490023344755173
# Step: 8000 of 15630, Predicted value: [86.407104], Actual Value: 87.0
# Loss is 0.35152506828308105
# Step: 9000 of 15630, Predicted value: [74.911446], Actual Value: 77.0
# Loss is 4.362059593200684
# Step: 10000 of 15630, Predicted value: [84.8709], Actual Value: 82.0
# Loss is 8.242084503173828
# Step: 11000 of 15630, Predicted value: [106.98469], Actual Value: 114.0
# Loss is 49.214603424072266
# Step: 12000 of 15630, Predicted value: [5.0421515], Actual Value: 3.0
# Loss is 4.170382499694824
# Step: 13000 of 15630, Predicted value: [112.468506], Actual Value: 90.0
# Loss is 504.8337707519531
# Step: 14000 of 15630, Predicted value: [151.6165], Actual Value: 256.0
# Loss is 10895.9150390625
# Step: 15000 of 15630, Predicted value: [90.034615], Actual Value: 88.0
# Loss is 4.1396565437316895
# -----------
# Epoch error is 693.6353689407703
# -----------
# Step: 0 of 15630, Predicted value: [130.77246], Actual Value: 142.0
# Loss is 126.05763244628906
# Step: 1000 of 15630, Predicted value: [6.372323], Actual Value: 4.0
# Loss is 5.6279168128967285
# Step: 2000 of 15630, Predicted value: [65.85311], Actual Value: 59.0
# Loss is 46.96513366699219
# Step: 3000 of 15630, Predicted value: [115.339806], Actual Value: 168.0
# Loss is 2773.09619140625
# Step: 4000 of 15630, Predicted value: [9.22208], Actual Value: 9.0
# Loss is 0.04931962862610817
# Step: 5000 of 15630, Predicted value: [125.313576], Actual Value: 107.0
# Loss is 335.3870544433594
# Step: 6000 of 15630, Predicted value: [137.82327], Actual Value: 138.0
# Loss is 0.03123253583908081
# Step: 7000 of 15630, Predicted value: [98.091], Actual Value: 96.0
# Loss is 4.372295379638672
# Step: 8000 of 15630, Predicted value: [84.8255], Actual Value: 87.0
# Loss is 4.728447914123535
# Step: 9000 of 15630, Predicted value: [75.97588], Actual Value: 77.0
# Loss is 1.0488146543502808
# Step: 10000 of 15630, Predicted value: [87.462814], Actual Value: 82.0
# Loss is 29.84234046936035
# Step: 11000 of 15630, Predicted value: [109.8133], Actual Value: 114.0
# Loss is 17.5284481048584
# Step: 12000 of 15630, Predicted value: [1.5622978], Actual Value: 3.0
# Loss is 2.0669875144958496
# Step: 13000 of 15630, Predicted value: [99.18933], Actual Value: 90.0
# Loss is 84.44380187988281
# Step: 14000 of 15630, Predicted value: [123.923676], Actual Value: 256.0
# Loss is 17444.15625
# Step: 15000 of 15630, Predicted value: [94.211914], Actual Value: 88.0
# Loss is 38.58787536621094
# -----------
# Epoch error is 661.6304848615491
# -----------
# Step: 0 of 15630, Predicted value: [145.8411], Actual Value: 142.0
# Loss is 14.754010200500488
# Step: 1000 of 15630, Predicted value: [5.673233], Actual Value: 4.0
# Loss is 2.799708843231201
# Step: 2000 of 15630, Predicted value: [63.04904], Actual Value: 59.0
# Loss is 16.394739151000977
# Step: 3000 of 15630, Predicted value: [107.130516], Actual Value: 168.0
# Loss is 3705.093994140625
# Step: 4000 of 15630, Predicted value: [8.797553], Actual Value: 9.0
# Loss is 0.04098476096987724
# Step: 5000 of 15630, Predicted value: [104.285736], Actual Value: 107.0
# Loss is 7.3672285079956055
# Step: 6000 of 15630, Predicted value: [125.68932], Actual Value: 138.0
# Loss is 151.55276489257812
# Step: 7000 of 15630, Predicted value: [95.7809], Actual Value: 96.0
# Loss is 0.048005226999521255
# Step: 8000 of 15630, Predicted value: [86.53787], Actual Value: 87.0
# Loss is 0.2135619968175888
# Step: 9000 of 15630, Predicted value: [73.693726], Actual Value: 77.0
# Loss is 10.931450843811035
# Step: 10000 of 15630, Predicted value: [88.01534], Actual Value: 82.0
# Loss is 36.184349060058594
# Step: 11000 of 15630, Predicted value: [116.66358], Actual Value: 114.0
# Loss is 7.094668388366699
# Step: 12000 of 15630, Predicted value: [2.2203188], Actual Value: 3.0
# Loss is 0.6079027652740479
# Step: 13000 of 15630, Predicted value: [86.61155], Actual Value: 90.0
# Loss is 11.481597900390625
# Step: 14000 of 15630, Predicted value: [177.1152], Actual Value: 256.0
# Loss is 6222.81103515625
# Step: 15000 of 15630, Predicted value: [86.80259], Actual Value: 88.0
# Loss is 1.4337921142578125
# -----------
# Epoch error is 660.6966628389836
# -----------

# %%
epocherror = []

for i in range(num_epochs):
  epocherror.append(sum(kfold_singleloss_list[i])/len(kfold_singleloss_list[i]))

x = range(num_epochs)
plt.plot(x,epocherror)

# %% [markdown]
# ## Test

# %%
# initialize testing lists
testdata_list = []
alltestunitdata_list = []
alltestunitdata_scaled_list = []
testfailurecycle_list = []
unit_list = []
rul_list = []

# run through each of the 4 testing files
for i in range(files):
    
    # read in testing data, one file at a time
    test = pd.read_csv(test_data[i],delimiter=' ',header=None)
    rul = pd.read_csv(rul_data[i],delimiter=' ',header=None)
    
    # drop NA in RUL data
    rul.dropna(axis=1,how='all',inplace=True)
    
    # initialize starting index for each unit collection
    startindex = 0
    
    # initialize list of unit data, this will seperate out each file into a 
    # seperate entry in a list
    unitdata_list = []
    
    unitnumber = 0
    
    # run through an individual testing file to pull out groups of unit data
    for k in range(len(test)-1):
        
        # check the unit number of the next line, if they are different then 
        # this k value represents the end of a grouping of units
        if test.iloc[k,0] != test.iloc[k+1,0]:
            # the last index in the unit group
            endindex = k
            
            # all of the data in the unit group, as defined by the start and
            # end index values
            unitdata = test.iloc[startindex:endindex,:]
            # drop columns with NA values
            unitdata.dropna(axis=1,how='all',inplace=True)
            # add unit number to list before dropping
            unit_list.append(unitdata.iloc[0,0])            
            # drop unit number as it isn't relevant to predictions
            unitdata = unitdata.iloc[:,1:]
            # drop uncorrelated columns
            unitdata.drop(unitdata.columns[[3,4,8,13,19,21,22]],axis=1,inplace=True)

            # scale values
            unitdata_cycles = unitdata.iloc[:,0].to_numpy()
            unitdata_scaled = input_scale.fit_transform(unitdata.iloc[:,1:])
            unitdata_scaled = np.column_stack((unitdata_cycles,unitdata_scaled))

            # in the testing data, we assume it failed during the last cycle
            failurecycle = rul.iloc[unitnumber] + unitdata_cycles[-1]
            rul_list.append(rul.iloc[unitnumber].to_numpy())
            
            # update the starting index to the next unit group
            startindex = endindex + 1
            
            # append to lists
            testfailurecycle_list.append(failurecycle.values)
            unitdata_list.append(unitdata)
            alltestunitdata_list.append(unitdata)
            alltestunitdata_scaled_list.append(unitdata_scaled)
            
            unitnumber += 1
            
        # collecting the last unit of the dataset    
        elif k == len(test)-2:
            # the last index in the unit group
            endindex = k
            
            # all of the data in the unit group, as defined by the start and
            # end index values
            unitdata = test.iloc[startindex:endindex,:]
            # drop columns with NA values
            unitdata.dropna(axis=1,how='all',inplace=True)
            # add unit number to list before dropping
            unit_list.append(unitdata.iloc[0,0]) 
            # drop unit number as it isn't relevant to predictions
            unitdata = unitdata.iloc[:,1:]
            # drop uncorrelated columns
            unitdata.drop(unitdata.columns[[3,4,8,13,19,21,22]],axis=1,inplace=True)
            
            # scale values
            unitdata_cycles = unitdata.iloc[:,0].to_numpy()
            unitdata_scaled = input_scale.fit_transform(unitdata.iloc[:,1:])
            unitdata_scaled = np.column_stack((unitdata_cycles,unitdata_scaled))
            # in the testing data, we assume it failed during the last cycle
            failurecycle = rul.iloc[unitnumber] + unitdata_cycles[-1]
            rul_list.append(rul.iloc[unitnumber].to_numpy())
            
            # update the starting index to the next unit group
            startindex = endindex + 1
            
            # append to lists
            testfailurecycle_list.append(failurecycle.values)
            unitdata_list.append(unitdata)
            alltestunitdata_list.append(unitdata)
            alltestunitdata_scaled_list.append(unitdata_scaled)
            
            unitnumber += 1
            
            
            
    # append to list where each item is for a different file
    testdata_list.append(unitdata_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
datapoints = 50

groupedtestData_list = []
test_predict_list = []
predictions_list = []
removeindex = []

for i in range(len(alltestunitdata_scaled_list)):
    if len(alltestunitdata_scaled_list[i]) < datapoints:
        print(i)
        removeindex.append(i)

for k in range(len(removeindex)):
    removerow = removeindex[len(removeindex)-(k+1)]
    del alltestunitdata_scaled_list[removerow]
    del testfailurecycle_list[removerow]
    del unit_list[removerow]
    del rul_list[removerow]


for j in range(len(alltestunitdata_scaled_list)):
    # pull out a single dataset from the training data
    dataset = alltestunitdata_scaled_list[j]
    # pull out the number of cycles for failure of that training dataset
    failurecycle = testfailurecycle_list[j]
    
    predictions = []
    # for each set of trainin data, group the data into datapoint number of rows
    # and attach the failure cycle to end
    for i in range(len(dataset)-datapoints+1):
        # RUL calculation
        RULentry = failurecycle - (i+datapoints)
        # select number of datapoints from training data
        groupedDataset = dataset[i:(i+datapoints),:]
        # make a list of the grouped data and the failures to cycle it should predict
        groupedData_entry = [groupedDataset,RULentry]
        # put all the data into a list
        groupedtestData_list.append(groupedData_entry)
        
        test_tensor = torch.tensor(groupedDataset).float()

        test_predict = model(test_tensor.cuda())

        predictions.append(test_predict.detach().cpu().numpy())
    
    test_singleprediction = predictions[-1]
    test_predict_list.append(test_singleprediction)
    predictions_list.append(predictions)

    # print('Prediction: {}, RUL: {}'.format(test_singleprediction,failurecycle))
# Out:
# 0
# 1
# 13
# 21
# 24
# 32
# 38
# 84

# %%
trainingunit_np = np.array(trainingunit_list)
trainfailurecycle_np = np.array(trainfailurecycle_list)
unit_np = np.array(unit_list)
testfailurecycle_np = np.array(testfailurecycle_list)

plt.figure()
plt.scatter(trainingunit_np,trainfailurecycle_np)
plt.scatter(unit_np,testfailurecycle_np)
plt.ylabel('Cycles at failure')
plt.xlabel('Unit Number')
plt.title('Training vs. Test Set Cyles at Failure')
plt.legend(('Training','Test'))

# %%
step_np = range(len(test_predict_list))
test_predict_np = np.array(test_predict_list)
testfailurecycle_np = np.array(testfailurecycle_list)
RUL_np = np.array(rul_list)

plt.figure()
plt.scatter(step_np,test_predict_np)
plt.scatter(step_np,RUL_np)
plt.ylabel('Remaining Useful Life [cycles]',size=14)
plt.xlabel('Steps',size=14)
plt.legend(('Prediction','Actual'))
plt.rcParams["figure.figsize"] = (10,6)

# %%
unit_np = np.array(unit_list)
test_predict_np = np.array(test_predict_list)
testfailurecycle_np = np.array(testfailurecycle_list)
RUL_np = np.array(rul_list)

plt.figure()
plt.scatter(unit_np,test_predict_np)
plt.scatter(unit_np,RUL_np)
plt.ylabel('Remaining Useful Life [cycles]',size=14)
plt.xlabel('Unit Number',size=14)
plt.legend(('Prediction','Actual'))
