# %% [markdown]
# <a href="https://colab.research.google.com/github/kvelez-iastate/S2021_ME592/blob/project/11_%7C_2_Layer_LSTM_%7C_50_Datapoints_%7C_1_File_%7C_30_Epochs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Input

# %%
import os, sys
from google.colab import drive
drive.mount('/content/mnt')
nb_path = '/content/notebooks'
os.symlink('/content/mnt/My Drive/Colab Notebooks/ME592/Project', nb_path)
sys.path.insert(0, nb_path)
# Out:
# Mounted at /content/mnt

# %%
#%%

import sys
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib import cm
import pandas as pd

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable

import re
from sklearn.preprocessing import PolynomialFeatures
from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold

# %%
#%%

path = r'/content/mnt/My Drive/Colab Notebooks/ME592/Project/NASA_TurboData/CMaps'
# path = r'C:\Users\ks07142\OneDrive-Deere&Co\OneDrive - Deere & Co\Graduate School\Spring2021_ME592\Project\NASA_TurboData\CMaps'

# loop through sub-directories and make a list of the paths to all data files
file_paths = []
for root, dirs, files in os.walk(path, topdown = True):
   for name in files:
      file_paths.append(os.path.join(root, name))


# Group Test data
test_data = []
for i in range(len(file_paths)):
  if 'test' in file_paths[i]:
    test_data.append(file_paths[i])
test_data = sorted(test_data)

# Group Train data
train_data = []
for i in range(len(file_paths)):
  if 'train' in file_paths[i]:
    train_data.append(file_paths[i])
train_data = sorted(train_data)

# Group Remaining Useful Life (RUL) data
rul_data = []
for i in range(len(file_paths)):
  if 'RUL' in file_paths[i]:
    rul_data.append(file_paths[i])
rul_data = sorted(rul_data)

# initialize normalization scale factors
input_scale = preprocessing.MinMaxScaler()
rul_scale = preprocessing.MinMaxScaler()

# initialize training lists
traindata_list = []
alltrainunitdata_list = []
alltrainunitdata_scaled_list = []
trainfailurecycle_list = []
trainingunit_list = []

files = 1
# run through each of the 4 training files
for i in range(files):
    
    # read in training data, one file at a time
    train = pd.read_csv(train_data[i],delimiter=' ',header=None)
    
    # initialize starting index for each unit collection
    startindex = 0
    
    # initialize list of unit data, this will seperate out each file into a 
    # seperate entry in a list
    unitdata_list = []
    
    # run through an individual training file to pull out groups of unit data
    for k in range(len(train)-1):
        
        # check the unit number of the next line, if they are different then 
        # this k value represents the end of a grouping of units
        if train.iloc[k,0] != train.iloc[k+1,0]:
            # the last index in the unit group
            endindex = k
            
            # all of the data in the unit group, as defined by the start and
            # end index values
            unitdata = train.iloc[startindex:endindex,:]
            # drop columns with NA values
            unitdata.dropna(axis=1,how='all',inplace=True)
            # add unit number to list before dropping
            trainingunit_list.append(unitdata.iloc[0,0])  
            # drop unit number as it isn't relevant to predictions
            unitdata = unitdata.iloc[:,1:]
            # drop uncorrelated columns
            unitdata.drop(unitdata.columns[[3,4,8,13,19,21,22]],axis=1,inplace=True)

            # scale values
            # unitdata_scaled = input_scale.fit_transform(unitdata)
            unitdata_cycles = unitdata.iloc[:,0].to_numpy()
            unitdata_scaled = input_scale.fit_transform(unitdata.iloc[:,1:])
            unitdata_scaled = np.column_stack((unitdata_cycles,unitdata_scaled))

            # in the training data, we assume it failed during the last cycle
            failurecycle = train.iloc[endindex,1]
            
            # update the starting index to the next unit group
            startindex = endindex + 1
            
            # append to lists
            trainfailurecycle_list.append(failurecycle)
            unitdata_list.append(unitdata)
            alltrainunitdata_list.append(unitdata)
            alltrainunitdata_scaled_list.append(unitdata_scaled)

        elif k == len(train)-2:
            # the last index in the unit group
            endindex = k
            
            # all of the data in the unit group, as defined by the start and
            # end index values
            unitdata = train.iloc[startindex:endindex,:]
            # drop columns with NA values
            unitdata.dropna(axis=1,how='all',inplace=True)
            # add unit number to list before dropping
            trainingunit_list.append(unitdata.iloc[0,0])
            # drop unit number as it isn't relevant to predictions
            unitdata = unitdata.iloc[:,1:]
            # drop uncorrelated columns
            unitdata.drop(unitdata.columns[[3,4,8,13,19,21,22]],axis=1,inplace=True)
            
            # scale values
            unitdata_cycles = unitdata.iloc[:,0].to_numpy()
            unitdata_scaled = input_scale.fit_transform(unitdata.iloc[:,1:])
            unitdata_scaled = np.column_stack((unitdata_cycles,unitdata_scaled))
            # in the training data, we assume it failed during the last cycle
            failurecycle = train.iloc[endindex,1]
            
            # update the starting index to the next unit group
            startindex = endindex + 1
            
            # append to lists
            trainfailurecycle_list.append(failurecycle)
            unitdata_list.append(unitdata)
            alltrainunitdata_list.append(unitdata)
            alltrainunitdata_scaled_list.append(unitdata_scaled)
            
            
    # append to list where each item is for a different file
    traindata_list.append(unitdata_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
trainingunit_np = np.array(trainingunit_list)
trainfailurecycle_np = np.array(trainfailurecycle_list)

plt.figure()
plt.scatter(trainingunit_np,trainfailurecycle_np)
# plt.scatter(unit_np,rul_np)
plt.ylabel('Total Cycles [cycles]')
plt.xlabel('Unit Number')
plt.title('Training Set Failures')
# plt.legend(('Prediction','Actual'))
# Out:
# Text(0.5, 1.0, 'Training Set Failures')

# %% [markdown]
# ## Model Training

# %%
#%% 
# sort into grouping of data with specified number of rows

datapoints = 50

groupedtrainData_list = []
removeindex = []

for i in range(len(alltrainunitdata_scaled_list)):
    if len(alltrainunitdata_scaled_list[i]) < datapoints:
        print(i)
        removeindex.append(i)

for k in range(len(removeindex)):
    removerow = removeindex[len(removeindex)-(k+1)]
    print(removeindex[len(removeindex)-(k+1)]) 
    del alltrainunitdata_scaled_list[removerow]
    del trainfailurecycle_list[removerow]

for j in range(len(alltrainunitdata_scaled_list)):
    # pull out a single dataset from the training data
    dataset = alltrainunitdata_scaled_list[j]
    # pull out the number of cycles for failure of that training dataset
    failurecycle = trainfailurecycle_list[j]
    
    # for each set of trainin data, group the data into datapoint number of rows
    # and attach the failure cycle to end
    for i in range(len(dataset)-datapoints+1):
        # RUL calculation
        RULentry = failurecycle - (i+datapoints)
        # select number of datapoints from training data
        groupedDataset = dataset[i:(i+datapoints),:]
        # make a list of the grouped data and the failures to cycle it should predict
        groupedData_entry = [groupedDataset,RULentry]
        # put all the data into a list
        groupedtrainData_list.append(groupedData_entry)

# %%
#%%

# neural network parameters
learning_rate = 0.001
hiddenlayers = 100
n_folds = 5

class MLModel(nn.Module):
    def __init__(self, input_size=25, hidden_layer_size=hiddenlayers, output_size=1):
        super().__init__()
        self.hidden_layer_size = hidden_layer_size

        self.lstm = nn.LSTM(input_size, hidden_layer_size)

        self.linear = nn.Linear(hidden_layer_size, output_size)

        self.hidden_cell = (torch.zeros(1,1,self.hidden_layer_size),
                            torch.zeros(1,1,self.hidden_layer_size))

    def forward(self, input_seq):
        lstm_out, self.hidden_cell = self.lstm(input_seq.view(len(input_seq) ,1, -1), self.hidden_cell)
        predictions = self.linear(lstm_out.view(len(input_seq), -1))
        return predictions[-1]

# %% [markdown]
# ### 100 LSTM, 50 LSTM, Linear

# %%
#%%

# neural network parameters
learning_rate = 0.001
hiddenlayers1 = 100
hiddenlayers2 = 50
n_folds = 5

class MLModel(nn.Module):
    def __init__(self, input_size=18, hidden_layer_size1=hiddenlayers1, hidden_layer_size2=hiddenlayers2, output_size=1):
        super().__init__()
        self.hidden_layer_size1 = hidden_layer_size1

        self.hidden_layer_size2 = hidden_layer_size2

        self.lstm1 = nn.LSTM(input_size, hidden_layer_size1)

        self.lstm2 = nn.LSTM(hidden_layer_size1, hidden_layer_size2)

        self.linear = nn.Linear(hidden_layer_size2, output_size)

        self.hidden_cell1 = (torch.zeros(1,1,self.hidden_layer_size1),
                            torch.zeros(1,1,self.hidden_layer_size1))
        
        self.hidden_cell2 = (torch.zeros(1,1,self.hidden_layer_size2),
                            torch.zeros(1,1,self.hidden_layer_size2))

    def forward(self, input_seq):
        lstm_out1, self.hidden_cell1 = self.lstm1(input_seq.view(len(input_seq) ,1, -1), self.hidden_cell1)
        lstm_out2, self.hidden_cell2 = self.lstm2(lstm_out1, self.hidden_cell2)
        predictions = self.linear(lstm_out2.view(len(input_seq), -1))
        return predictions[-1]

# %% [markdown]
# ### epochs

# %%
#%%

model = MLModel()
model = model.cuda()
loss_function = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
k_fold = KFold(n_splits = n_folds, shuffle=False)

# covnert list to np array
groupedtrainData_np = np.array(groupedtrainData_list)

# Collect kfold loss to plot later
kfold_singleloss_list = []

num_epochs = 30

for epoch in range(num_epochs):
    trainfold = groupedtrainData_np
    traininput = trainfold[:,0]
    trainoutput = trainfold[:,1]
    
    singleloss_list = []

    for k in range(len(trainfold)):
        traininput_tensor = torch.tensor(traininput[k]).float()
        trainoutput_tensor = torch.tensor(trainoutput[k]).float()

        traininput_tensor = traininput_tensor
        trainoutput_tensor = trainoutput_tensor
        
        foldloss = 0
        optimizer.zero_grad()
        model.hidden_cell1 = (torch.zeros(1, 1, model.hidden_layer_size1).cuda(),
                      torch.zeros(1, 1, model.hidden_layer_size1).cuda())
        model.hidden_cell2 = (torch.zeros(1, 1, model.hidden_layer_size2).cuda(),
                      torch.zeros(1, 1, model.hidden_layer_size2).cuda())
        
        y_pred = model(traininput_tensor.cuda())
        single_loss = loss_function(y_pred, trainoutput_tensor.cuda())
        single_loss.backward()
        optimizer.step()
        
        singleloss_list.append(single_loss.detach().cpu().numpy())

        if k % 1000 == 0:
            text1 = 'Step: {} of {}, Predicted value: {}, Actual Value: {}'.format(k, len(trainfold), y_pred.detach().cpu().numpy(),trainoutput_tensor)
            print(text1)
            text = 'Loss is {}'.format(single_loss)
            print(text)
            
    kfold_singleloss_list.append(singleloss_list)
    
    text2 = 'Epoch {} of {} error is {}'.format(epoch,num_epochs,sum(kfold_singleloss_list[epoch])/len(kfold_singleloss_list[epoch]))
    print('-----------')
    print(text2)
    print('-----------')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/loss.py:528: UserWarning: Using a target size (torch.Size([])) that is different to the input size (torch.Size([1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Step: 0 of 15630, Predicted value: [0.07066023], Actual Value: 142.0
# Loss is 20143.9375
# Step: 1000 of 15630, Predicted value: [36.809563], Actual Value: 4.0
# Loss is 1076.4674072265625
# Step: 2000 of 15630, Predicted value: [47.232563], Actual Value: 59.0
# Loss is 138.4725799560547
# Step: 3000 of 15630, Predicted value: [62.53881], Actual Value: 168.0
# Loss is 11122.0625
# Step: 4000 of 15630, Predicted value: [69.09521], Actual Value: 9.0
# Loss is 3611.433837890625
# Step: 5000 of 15630, Predicted value: [71.240776], Actual Value: 107.0
# Loss is 1278.7220458984375
# Step: 6000 of 15630, Predicted value: [68.180305], Actual Value: 138.0
# Loss is 4874.78955078125
# Step: 7000 of 15630, Predicted value: [73.75883], Actual Value: 96.0
# Loss is 494.6697692871094
# Step: 8000 of 15630, Predicted value: [99.615616], Actual Value: 87.0
# Loss is 159.1537628173828
# Step: 9000 of 15630, Predicted value: [78.45067], Actual Value: 77.0
# Loss is 2.104438543319702
# Step: 10000 of 15630, Predicted value: [84.70718], Actual Value: 82.0
# Loss is 7.328803062438965
# Step: 11000 of 15630, Predicted value: [100.78984], Actual Value: 114.0
# Loss is 174.50831604003906
# Step: 12000 of 15630, Predicted value: [3.8155289], Actual Value: 3.0
# Loss is 0.6650873422622681
# Step: 13000 of 15630, Predicted value: [137.80869], Actual Value: 90.0
# Loss is 2285.67041015625
# Step: 14000 of 15630, Predicted value: [129.64613], Actual Value: 256.0
# Loss is 15965.2998046875
# Step: 15000 of 15630, Predicted value: [92.66672], Actual Value: 88.0
# Loss is 21.77825164794922
# -----------
# Epoch 0 of 30 error is 2468.344060919829
# -----------
# Step: 0 of 15630, Predicted value: [109.31649], Actual Value: 142.0
# Loss is 1068.2117919921875
# Step: 1000 of 15630, Predicted value: [13.157972], Actual Value: 4.0
# Loss is 83.86845397949219
# Step: 2000 of 15630, Predicted value: [45.16468], Actual Value: 59.0
# Loss is 191.4160614013672
# Step: 3000 of 15630, Predicted value: [115.5096], Actual Value: 168.0
# Loss is 2755.242431640625
# Step: 4000 of 15630, Predicted value: [9.658007], Actual Value: 9.0
# Loss is 0.43297278881073
# Step: 5000 of 15630, Predicted value: [122.53328], Actual Value: 107.0
# Loss is 241.28277587890625
# Step: 6000 of 15630, Predicted value: [128.97778], Actual Value: 138.0
# Loss is 81.40039825439453
# Step: 7000 of 15630, Predicted value: [97.314804], Actual Value: 96.0
# Loss is 1.7287098169326782
# Step: 8000 of 15630, Predicted value: [83.08599], Actual Value: 87.0
# Loss is 15.319467544555664
# Step: 9000 of 15630, Predicted value: [74.52395], Actual Value: 77.0
# Loss is 6.13083028793335
# Step: 10000 of 15630, Predicted value: [84.65213], Actual Value: 82.0
# Loss is 7.033794403076172
# Step: 11000 of 15630, Predicted value: [121.625175], Actual Value: 114.0
# Loss is 58.14330291748047
# Step: 12000 of 15630, Predicted value: [4.24517], Actual Value: 3.0
# Loss is 1.5504486560821533
# Step: 13000 of 15630, Predicted value: [91.45437], Actual Value: 90.0
# Loss is 2.115187883377075
# Step: 14000 of 15630, Predicted value: [149.3751], Actual Value: 256.0
# Loss is 11368.8681640625
# Step: 15000 of 15630, Predicted value: [89.41127], Actual Value: 88.0
# Loss is 1.9916833639144897
# -----------
# Epoch 1 of 30 error is 989.6506784473602
# -----------
# Step: 0 of 15630, Predicted value: [134.8478], Actual Value: 142.0
# Loss is 51.154056549072266
# Step: 1000 of 15630, Predicted value: [6.014065], Actual Value: 4.0
# Loss is 4.056457042694092
# Step: 2000 of 15630, Predicted value: [58.515522], Actual Value: 59.0
# Loss is 0.2347189337015152
# Step: 3000 of 15630, Predicted value: [109.99394], Actual Value: 168.0
# Loss is 3364.70263671875
# Step: 4000 of 15630, Predicted value: [9.982145], Actual Value: 9.0
# Loss is 0.9646093845367432
# Step: 5000 of 15630, Predicted value: [125.44545], Actual Value: 107.0
# Loss is 340.234619140625
# Step: 6000 of 15630, Predicted value: [117.45287], Actual Value: 138.0
# Loss is 422.1844177246094
# Step: 7000 of 15630, Predicted value: [94.76992], Actual Value: 96.0
# Loss is 1.5130959749221802
# Step: 8000 of 15630, Predicted value: [83.399635], Actual Value: 87.0
# Loss is 12.962625503540039
# Step: 9000 of 15630, Predicted value: [81.36909], Actual Value: 77.0
# Loss is 19.08892250061035
# Step: 10000 of 15630, Predicted value: [89.35006], Actual Value: 82.0
# Loss is 54.02337646484375
# Step: 11000 of 15630, Predicted value: [130.34933], Actual Value: 114.0
# Loss is 267.3007507324219
# Step: 12000 of 15630, Predicted value: [1.882689], Actual Value: 3.0
# Loss is 1.24838387966156
# Step: 13000 of 15630, Predicted value: [140.40346], Actual Value: 90.0
# Loss is 2540.508544921875
# Step: 14000 of 15630, Predicted value: [134.68362], Actual Value: 256.0
# Loss is 14717.6630859375
# Step: 15000 of 15630, Predicted value: [87.2324], Actual Value: 88.0
# Loss is 0.5892113447189331
# -----------
# Epoch 2 of 30 error is 1030.2933858595898
# -----------
# Step: 0 of 15630, Predicted value: [113.78069], Actual Value: 142.0
# Loss is 796.3292846679688
# Step: 1000 of 15630, Predicted value: [5.0566487], Actual Value: 4.0
# Loss is 1.116506576538086
# Step: 2000 of 15630, Predicted value: [59.64567], Actual Value: 59.0
# Loss is 0.4168921411037445
# Step: 3000 of 15630, Predicted value: [123.54914], Actual Value: 168.0
# Loss is 1975.87890625
# Step: 4000 of 15630, Predicted value: [9.282134], Actual Value: 9.0
# Loss is 0.07959962636232376
# Step: 5000 of 15630, Predicted value: [124.13142], Actual Value: 107.0
# Loss is 293.48541259765625
# Step: 6000 of 15630, Predicted value: [114.56186], Actual Value: 138.0
# Loss is 549.346435546875
# Step: 7000 of 15630, Predicted value: [96.50048], Actual Value: 96.0
# Loss is 0.25048089027404785
# Step: 8000 of 15630, Predicted value: [85.87335], Actual Value: 87.0
# Loss is 1.2693356275558472
# Step: 9000 of 15630, Predicted value: [78.568275], Actual Value: 77.0
# Loss is 2.4594879150390625
# Step: 10000 of 15630, Predicted value: [88.88915], Actual Value: 82.0
# Loss is 47.46042251586914
# Step: 11000 of 15630, Predicted value: [118.24205], Actual Value: 114.0
# Loss is 17.9949893951416
# Step: 12000 of 15630, Predicted value: [2.4003394], Actual Value: 3.0
# Loss is 0.35959288477897644
# Step: 13000 of 15630, Predicted value: [87.97591], Actual Value: 90.0
# Loss is 4.096954822540283
# Step: 14000 of 15630, Predicted value: [140.6528], Actual Value: 256.0
# Loss is 13304.9765625
# Step: 15000 of 15630, Predicted value: [85.2632], Actual Value: 88.0
# Loss is 7.4900803565979
# -----------
# Epoch 3 of 30 error is 897.6280962091614
# -----------
# Step: 0 of 15630, Predicted value: [128.82297], Actual Value: 142.0
# Loss is 173.63418579101562
# Step: 1000 of 15630, Predicted value: [4.66368], Actual Value: 4.0
# Loss is 0.44047123193740845
# Step: 2000 of 15630, Predicted value: [60.18216], Actual Value: 59.0
# Loss is 1.3975008726119995
# Step: 3000 of 15630, Predicted value: [137.41998], Actual Value: 168.0
# Loss is 935.137451171875
# Step: 4000 of 15630, Predicted value: [10.296807], Actual Value: 9.0
# Loss is 1.6817091703414917
# Step: 5000 of 15630, Predicted value: [128.57341], Actual Value: 107.0
# Loss is 465.4120178222656
# Step: 6000 of 15630, Predicted value: [140.4527], Actual Value: 138.0
# Loss is 6.015726089477539
# Step: 7000 of 15630, Predicted value: [96.632], Actual Value: 96.0
# Loss is 0.3994287848472595
# Step: 8000 of 15630, Predicted value: [87.35227], Actual Value: 87.0
# Loss is 0.12409558892250061
# Step: 9000 of 15630, Predicted value: [72.948456], Actual Value: 77.0
# Loss is 16.415010452270508
# Step: 10000 of 15630, Predicted value: [81.61619], Actual Value: 82.0
# Loss is 0.14731161296367645
# Step: 11000 of 15630, Predicted value: [62.64571], Actual Value: 114.0
# Loss is 2637.26318359375
# Step: 12000 of 15630, Predicted value: [15.011308], Actual Value: 3.0
# Loss is 144.27151489257812
# Step: 13000 of 15630, Predicted value: [89.44606], Actual Value: 90.0
# Loss is 0.30684933066368103
# Step: 14000 of 15630, Predicted value: [94.742836], Actual Value: 256.0
# Loss is 26003.875
# Step: 15000 of 15630, Predicted value: [91.00408], Actual Value: 88.0
# Loss is 9.024506568908691
# -----------
# Epoch 4 of 30 error is 1282.8737573226044
# -----------
# Step: 0 of 15630, Predicted value: [102.75688], Actual Value: 142.0
# Loss is 1540.0223388671875
# Step: 1000 of 15630, Predicted value: [7.627084], Actual Value: 4.0
# Loss is 13.155736923217773
# Step: 2000 of 15630, Predicted value: [62.012623], Actual Value: 59.0
# Loss is 9.075896263122559
# Step: 3000 of 15630, Predicted value: [123.74936], Actual Value: 168.0
# Loss is 1958.1192626953125
# Step: 4000 of 15630, Predicted value: [9.849403], Actual Value: 9.0
# Loss is 0.7214860916137695
# Step: 5000 of 15630, Predicted value: [121.64229], Actual Value: 107.0
# Loss is 214.3966064453125
# Step: 6000 of 15630, Predicted value: [127.132614], Actual Value: 138.0
# Loss is 118.1000747680664
# Step: 7000 of 15630, Predicted value: [100.23089], Actual Value: 96.0
# Loss is 17.900415420532227
# Step: 8000 of 15630, Predicted value: [84.11663], Actual Value: 87.0
# Loss is 8.31381893157959
# Step: 9000 of 15630, Predicted value: [82.75984], Actual Value: 77.0
# Loss is 33.175777435302734
# Step: 10000 of 15630, Predicted value: [82.93758], Actual Value: 82.0
# Loss is 0.8790493011474609
# Step: 11000 of 15630, Predicted value: [114.645294], Actual Value: 114.0
# Loss is 0.4164046049118042
# Step: 12000 of 15630, Predicted value: [3.4346523], Actual Value: 3.0
# Loss is 0.18892264366149902
# Step: 13000 of 15630, Predicted value: [135.01057], Actual Value: 90.0
# Loss is 2025.9517822265625
# Step: 14000 of 15630, Predicted value: [143.27792], Actual Value: 256.0
# Loss is 12706.2666015625
# Step: 15000 of 15630, Predicted value: [88.04942], Actual Value: 88.0
# Loss is 0.0024426544550806284
# -----------
# Epoch 5 of 30 error is 797.3897653925721
# -----------
# Step: 0 of 15630, Predicted value: [118.2142], Actual Value: 142.0
# Loss is 565.76416015625
# Step: 1000 of 15630, Predicted value: [5.9280415], Actual Value: 4.0
# Loss is 3.717343807220459
# Step: 2000 of 15630, Predicted value: [55.66147], Actual Value: 59.0
# Loss is 11.145792961120605
# Step: 3000 of 15630, Predicted value: [117.72045], Actual Value: 168.0
# Loss is 2528.032958984375
# Step: 4000 of 15630, Predicted value: [13.075064], Actual Value: 9.0
# Loss is 16.606143951416016
# Step: 5000 of 15630, Predicted value: [106.80362], Actual Value: 107.0
# Loss is 0.038565345108509064
# Step: 6000 of 15630, Predicted value: [117.516464], Actual Value: 138.0
# Loss is 419.5752258300781
# Step: 7000 of 15630, Predicted value: [93.97595], Actual Value: 96.0
# Loss is 4.0967698097229
# Step: 8000 of 15630, Predicted value: [85.365524], Actual Value: 87.0
# Loss is 2.671510934829712
# Step: 9000 of 15630, Predicted value: [82.20093], Actual Value: 77.0
# Loss is 27.049650192260742
# Step: 10000 of 15630, Predicted value: [81.59736], Actual Value: 82.0
# Loss is 0.1621200144290924
# Step: 11000 of 15630, Predicted value: [117.74405], Actual Value: 114.0
# Loss is 14.017903327941895
# Step: 12000 of 15630, Predicted value: [2.3527985], Actual Value: 3.0
# Loss is 0.41886982321739197
# Step: 13000 of 15630, Predicted value: [113.86884], Actual Value: 90.0
# Loss is 569.7216796875
# Step: 14000 of 15630, Predicted value: [135.66197], Actual Value: 256.0
# Loss is 14481.2412109375
# Step: 15000 of 15630, Predicted value: [84.85123], Actual Value: 88.0
# Loss is 9.914772987365723
# -----------
# Epoch 6 of 30 error is 622.5781726691486
# -----------
# Step: 0 of 15630, Predicted value: [130.43843], Actual Value: 142.0
# Loss is 133.6698760986328
# Step: 1000 of 15630, Predicted value: [3.9569683], Actual Value: 4.0
# Loss is 0.0018517265561968088
# Step: 2000 of 15630, Predicted value: [57.16671], Actual Value: 59.0
# Loss is 3.360952615737915
# Step: 3000 of 15630, Predicted value: [100.778114], Actual Value: 168.0
# Loss is 4518.78173828125
# Step: 4000 of 15630, Predicted value: [9.726343], Actual Value: 9.0
# Loss is 0.527574360370636
# Step: 5000 of 15630, Predicted value: [109.28131], Actual Value: 107.0
# Loss is 5.204380035400391
# Step: 6000 of 15630, Predicted value: [131.68611], Actual Value: 138.0
# Loss is 39.86518859863281
# Step: 7000 of 15630, Predicted value: [95.67633], Actual Value: 96.0
# Loss is 0.10476189851760864
# Step: 8000 of 15630, Predicted value: [86.60673], Actual Value: 87.0
# Loss is 0.15466317534446716
# Step: 9000 of 15630, Predicted value: [78.63793], Actual Value: 77.0
# Loss is 2.6828205585479736
# Step: 10000 of 15630, Predicted value: [81.53713], Actual Value: 82.0
# Loss is 0.21424654126167297
# Step: 11000 of 15630, Predicted value: [113.325356], Actual Value: 114.0
# Loss is 0.4551451504230499
# Step: 12000 of 15630, Predicted value: [3.4943495], Actual Value: 3.0
# Loss is 0.24438141286373138
# Step: 13000 of 15630, Predicted value: [93.27539], Actual Value: 90.0
# Loss is 10.72818374633789
# Step: 14000 of 15630, Predicted value: [157.30713], Actual Value: 256.0
# Loss is 9740.283203125
# Step: 15000 of 15630, Predicted value: [90.7905], Actual Value: 88.0
# Loss is 7.786872386932373
# -----------
# Epoch 7 of 30 error is 601.287364823015
# -----------
# Step: 0 of 15630, Predicted value: [129.60645], Actual Value: 142.0
# Loss is 153.60020446777344
# Step: 1000 of 15630, Predicted value: [5.931271], Actual Value: 4.0
# Loss is 3.7298078536987305
# Step: 2000 of 15630, Predicted value: [57.25465], Actual Value: 59.0
# Loss is 3.046246290206909
# Step: 3000 of 15630, Predicted value: [140.93088], Actual Value: 168.0
# Loss is 732.7373657226562
# Step: 4000 of 15630, Predicted value: [11.008242], Actual Value: 9.0
# Loss is 4.033034324645996
# Step: 5000 of 15630, Predicted value: [108.97553], Actual Value: 107.0
# Loss is 3.902728796005249
# Step: 6000 of 15630, Predicted value: [140.37267], Actual Value: 138.0
# Loss is 5.629540920257568
# Step: 7000 of 15630, Predicted value: [94.819115], Actual Value: 96.0
# Loss is 1.394490122795105
# Step: 8000 of 15630, Predicted value: [79.505974], Actual Value: 87.0
# Loss is 56.16042709350586
# Step: 9000 of 15630, Predicted value: [77.98797], Actual Value: 77.0
# Loss is 0.9760816693305969
# Step: 10000 of 15630, Predicted value: [86.007355], Actual Value: 82.0
# Loss is 16.05889129638672
# Step: 11000 of 15630, Predicted value: [124.760025], Actual Value: 114.0
# Loss is 115.77813720703125
# Step: 12000 of 15630, Predicted value: [5.3191485], Actual Value: 3.0
# Loss is 5.3784499168396
# Step: 13000 of 15630, Predicted value: [86.23631], Actual Value: 90.0
# Loss is 14.165340423583984
# Step: 14000 of 15630, Predicted value: [147.25392], Actual Value: 256.0
# Loss is 11825.7099609375
# Step: 15000 of 15630, Predicted value: [78.57186], Actual Value: 88.0
# Loss is 88.88980102539062
# -----------
# Epoch 8 of 30 error is 614.836569693891
# -----------
# Step: 0 of 15630, Predicted value: [129.07], Actual Value: 142.0
# Loss is 167.18470764160156
# Step: 1000 of 15630, Predicted value: [0.32883835], Actual Value: 4.0
# Loss is 13.47742748260498
# Step: 2000 of 15630, Predicted value: [55.600136], Actual Value: 59.0
# Loss is 11.559076309204102
# Step: 3000 of 15630, Predicted value: [136.22534], Actual Value: 168.0
# Loss is 1009.62890625
# Step: 4000 of 15630, Predicted value: [8.638881], Actual Value: 9.0
# Loss is 0.13040712475776672
# Step: 5000 of 15630, Predicted value: [109.43325], Actual Value: 107.0
# Loss is 5.920707702636719
# Step: 6000 of 15630, Predicted value: [135.73883], Actual Value: 138.0
# Loss is 5.112887382507324
# Step: 7000 of 15630, Predicted value: [97.53069], Actual Value: 96.0
# Loss is 2.3430211544036865
# Step: 8000 of 15630, Predicted value: [85.84863], Actual Value: 87.0
# Loss is 1.3256464004516602
# Step: 9000 of 15630, Predicted value: [73.316055], Actual Value: 77.0
# Loss is 13.57144832611084
# Step: 10000 of 15630, Predicted value: [98.28099], Actual Value: 82.0
# Loss is 265.0706481933594
# Step: 11000 of 15630, Predicted value: [118.65658], Actual Value: 114.0
# Loss is 21.683719635009766
# Step: 12000 of 15630, Predicted value: [12.370527], Actual Value: 3.0
# Loss is 87.80677795410156
# Step: 13000 of 15630, Predicted value: [84.89652], Actual Value: 90.0
# Loss is 26.045482635498047
# Step: 14000 of 15630, Predicted value: [200.75925], Actual Value: 256.0
# Loss is 3051.540771484375
# Step: 15000 of 15630, Predicted value: [94.671555], Actual Value: 88.0
# Loss is 44.509639739990234
# -----------
# Epoch 9 of 30 error is 534.1711593375941
# -----------
# Step: 0 of 15630, Predicted value: [122.04073], Actual Value: 142.0
# Loss is 398.372314453125
# Step: 1000 of 15630, Predicted value: [4.9360013], Actual Value: 4.0
# Loss is 0.8760984539985657
# Step: 2000 of 15630, Predicted value: [58.846165], Actual Value: 59.0
# Loss is 0.023665297776460648
# Step: 3000 of 15630, Predicted value: [155.3357], Actual Value: 168.0
# Loss is 160.38465881347656
# Step: 4000 of 15630, Predicted value: [10.781835], Actual Value: 9.0
# Loss is 3.1749346256256104
# Step: 5000 of 15630, Predicted value: [104.02904], Actual Value: 107.0
# Loss is 8.826618194580078
# Step: 6000 of 15630, Predicted value: [125.84169], Actual Value: 138.0
# Loss is 147.82449340820312
# Step: 7000 of 15630, Predicted value: [91.56516], Actual Value: 96.0
# Loss is 19.667781829833984
# Step: 8000 of 15630, Predicted value: [88.63206], Actual Value: 87.0
# Loss is 2.6636106967926025
# Step: 9000 of 15630, Predicted value: [76.364395], Actual Value: 77.0
# Loss is 0.40399354696273804
# Step: 10000 of 15630, Predicted value: [84.811356], Actual Value: 82.0
# Loss is 7.903720378875732
# Step: 11000 of 15630, Predicted value: [112.53407], Actual Value: 114.0
# Loss is 2.148942232131958
# Step: 12000 of 15630, Predicted value: [3.8464212], Actual Value: 3.0
# Loss is 0.7164289355278015
# Step: 13000 of 15630, Predicted value: [83.742966], Actual Value: 90.0
# Loss is 39.15047836303711
# Step: 14000 of 15630, Predicted value: [189.38113], Actual Value: 256.0
# Loss is 4438.0732421875
# Step: 15000 of 15630, Predicted value: [79.25691], Actual Value: 88.0
# Loss is 76.44158172607422
# -----------
# Epoch 10 of 30 error is 612.5318216854524
# -----------
# Step: 0 of 15630, Predicted value: [145.67892], Actual Value: 142.0
# Loss is 13.534485816955566
# Step: 1000 of 15630, Predicted value: [7.614857], Actual Value: 4.0
# Loss is 13.067192077636719
# Step: 2000 of 15630, Predicted value: [61.102253], Actual Value: 59.0
# Loss is 4.419467449188232
# Step: 3000 of 15630, Predicted value: [119.090904], Actual Value: 168.0
# Loss is 2392.099609375
# Step: 4000 of 15630, Predicted value: [9.905414], Actual Value: 9.0
# Loss is 0.8197738528251648
# Step: 5000 of 15630, Predicted value: [105.586105], Actual Value: 107.0
# Loss is 1.9990980625152588
# Step: 6000 of 15630, Predicted value: [128.28172], Actual Value: 138.0
# Loss is 94.44490814208984
# Step: 7000 of 15630, Predicted value: [97.3871], Actual Value: 96.0
# Loss is 1.9240469932556152
# Step: 8000 of 15630, Predicted value: [84.33874], Actual Value: 87.0
# Loss is 7.082318305969238
# Step: 9000 of 15630, Predicted value: [77.949844], Actual Value: 77.0
# Loss is 0.9022043347358704
# Step: 10000 of 15630, Predicted value: [87.221085], Actual Value: 82.0
# Loss is 27.259723663330078
# Step: 11000 of 15630, Predicted value: [117.22485], Actual Value: 114.0
# Loss is 10.399680137634277
# Step: 12000 of 15630, Predicted value: [5.162134], Actual Value: 3.0
# Loss is 4.674824237823486
# Step: 13000 of 15630, Predicted value: [90.5463], Actual Value: 90.0
# Loss is 0.29844674468040466
# Step: 14000 of 15630, Predicted value: [135.21371], Actual Value: 256.0
# Loss is 14589.3271484375
# Step: 15000 of 15630, Predicted value: [94.34093], Actual Value: 88.0
# Loss is 40.20735549926758
# -----------
# Epoch 11 of 30 error is 650.1995128967582
# -----------
# Step: 0 of 15630, Predicted value: [124.726265], Actual Value: 142.0
# Loss is 298.3819274902344
# Step: 1000 of 15630, Predicted value: [4.888874], Actual Value: 4.0
# Loss is 0.7900970578193665
# Step: 2000 of 15630, Predicted value: [60.23256], Actual Value: 59.0
# Loss is 1.5192022323608398
# Step: 3000 of 15630, Predicted value: [127.11089], Actual Value: 168.0
# Loss is 1671.9190673828125
# Step: 4000 of 15630, Predicted value: [9.677638], Actual Value: 9.0
# Loss is 0.45919331908226013
# Step: 5000 of 15630, Predicted value: [109.89995], Actual Value: 107.0
# Loss is 8.409699440002441
# Step: 6000 of 15630, Predicted value: [145.21562], Actual Value: 138.0
# Loss is 52.06520080566406
# Step: 7000 of 15630, Predicted value: [94.850464], Actual Value: 96.0
# Loss is 1.3214333057403564
# Step: 8000 of 15630, Predicted value: [83.34589], Actual Value: 87.0
# Loss is 13.352547645568848
# Step: 9000 of 15630, Predicted value: [75.24808], Actual Value: 77.0
# Loss is 3.069232940673828
# Step: 10000 of 15630, Predicted value: [82.50455], Actual Value: 82.0
# Loss is 0.25456780195236206
# Step: 11000 of 15630, Predicted value: [115.46784], Actual Value: 114.0
# Loss is 2.1545603275299072
# Step: 12000 of 15630, Predicted value: [10.3850975], Actual Value: 3.0
# Loss is 54.53966522216797
# Step: 13000 of 15630, Predicted value: [89.64665], Actual Value: 90.0
# Loss is 0.12485465407371521
# Step: 14000 of 15630, Predicted value: [149.61205], Actual Value: 256.0
# Loss is 11318.396484375
# Step: 15000 of 15630, Predicted value: [92.40681], Actual Value: 88.0
# Loss is 19.419946670532227
# -----------
# Epoch 12 of 30 error is 549.9845042667047
# -----------
# Step: 0 of 15630, Predicted value: [138.62402], Actual Value: 142.0
# Loss is 11.397217750549316
# Step: 1000 of 15630, Predicted value: [5.9947834], Actual Value: 4.0
# Loss is 3.979160785675049
# Step: 2000 of 15630, Predicted value: [59.068153], Actual Value: 59.0
# Loss is 0.004644883330911398
# Step: 3000 of 15630, Predicted value: [140.79721], Actual Value: 168.0
# Loss is 739.9917602539062
# Step: 4000 of 15630, Predicted value: [11.369045], Actual Value: 9.0
# Loss is 5.612375259399414
# Step: 5000 of 15630, Predicted value: [89.60162], Actual Value: 107.0
# Loss is 302.7034912109375
# Step: 6000 of 15630, Predicted value: [130.65303], Actual Value: 138.0
# Loss is 53.977962493896484
# Step: 7000 of 15630, Predicted value: [94.18877], Actual Value: 96.0
# Loss is 3.280566930770874
# Step: 8000 of 15630, Predicted value: [85.40509], Actual Value: 87.0
# Loss is 2.5437369346618652
# Step: 9000 of 15630, Predicted value: [78.11634], Actual Value: 77.0
# Loss is 1.2462164163589478
# Step: 10000 of 15630, Predicted value: [92.08429], Actual Value: 82.0
# Loss is 101.6928939819336
# Step: 11000 of 15630, Predicted value: [113.9019], Actual Value: 114.0
# Loss is 0.009623365476727486
# Step: 12000 of 15630, Predicted value: [7.5429583], Actual Value: 3.0
# Loss is 20.638469696044922
# Step: 13000 of 15630, Predicted value: [86.678894], Actual Value: 90.0
# Loss is 11.029745101928711
# Step: 14000 of 15630, Predicted value: [190.92714], Actual Value: 256.0
# Loss is 4234.47705078125
# Step: 15000 of 15630, Predicted value: [90.58905], Actual Value: 88.0
# Loss is 6.703181266784668
# -----------
# Epoch 13 of 30 error is 525.0406459264988
# -----------
# Step: 0 of 15630, Predicted value: [143.97731], Actual Value: 142.0
# Loss is 3.9097554683685303
# Step: 1000 of 15630, Predicted value: [8.332442], Actual Value: 4.0
# Loss is 18.770055770874023
# Step: 2000 of 15630, Predicted value: [56.389194], Actual Value: 59.0
# Loss is 6.816305637359619
# Step: 3000 of 15630, Predicted value: [132.2902], Actual Value: 168.0
# Loss is 1275.1893310546875
# Step: 4000 of 15630, Predicted value: [13.287561], Actual Value: 9.0
# Loss is 18.383182525634766
# Step: 5000 of 15630, Predicted value: [103.389854], Actual Value: 107.0
# Loss is 13.033150672912598
# Step: 6000 of 15630, Predicted value: [138.12366], Actual Value: 138.0
# Loss is 0.015291109681129456
# Step: 7000 of 15630, Predicted value: [94.15731], Actual Value: 96.0
# Loss is 3.3955047130584717
# Step: 8000 of 15630, Predicted value: [87.707886], Actual Value: 87.0
# Loss is 0.5011022090911865
# Step: 9000 of 15630, Predicted value: [77.443634], Actual Value: 77.0
# Loss is 0.19681115448474884
# Step: 10000 of 15630, Predicted value: [82.76551], Actual Value: 82.0
# Loss is 0.5860064029693604
# Step: 11000 of 15630, Predicted value: [117.39914], Actual Value: 114.0
# Loss is 11.55414867401123
# Step: 12000 of 15630, Predicted value: [4.1812754], Actual Value: 3.0
# Loss is 1.395411491394043
# Step: 13000 of 15630, Predicted value: [114.51125], Actual Value: 90.0
# Loss is 600.801513671875
# Step: 14000 of 15630, Predicted value: [186.66275], Actual Value: 256.0
# Loss is 4807.654296875
# Step: 15000 of 15630, Predicted value: [92.99072], Actual Value: 88.0
# Loss is 24.907312393188477
# -----------
# Epoch 14 of 30 error is 573.3442895361302
# -----------
# Step: 0 of 15630, Predicted value: [139.01242], Actual Value: 142.0
# Loss is 8.925630569458008
# Step: 1000 of 15630, Predicted value: [4.6490936], Actual Value: 4.0
# Loss is 0.4213225245475769
# Step: 2000 of 15630, Predicted value: [58.261642], Actual Value: 59.0
# Loss is 0.545171856880188
# Step: 3000 of 15630, Predicted value: [162.02657], Actual Value: 168.0
# Loss is 35.68191909790039
# Step: 4000 of 15630, Predicted value: [12.925146], Actual Value: 9.0
# Loss is 15.406771659851074
# Step: 5000 of 15630, Predicted value: [121.401634], Actual Value: 107.0
# Loss is 207.40707397460938
# Step: 6000 of 15630, Predicted value: [144.61853], Actual Value: 138.0
# Loss is 43.8049430847168
# Step: 7000 of 15630, Predicted value: [96.33994], Actual Value: 96.0
# Loss is 0.11556119471788406
# Step: 8000 of 15630, Predicted value: [85.9026], Actual Value: 87.0
# Loss is 1.204279899597168
# Step: 9000 of 15630, Predicted value: [79.21145], Actual Value: 77.0
# Loss is 4.890505313873291
# Step: 10000 of 15630, Predicted value: [82.00938], Actual Value: 82.0
# Loss is 8.791923755779862e-05
# Step: 11000 of 15630, Predicted value: [111.97913], Actual Value: 114.0
# Loss is 4.0839009284973145
# Step: 12000 of 15630, Predicted value: [2.309929], Actual Value: 3.0
# Loss is 0.47619813680648804
# Step: 13000 of 15630, Predicted value: [109.77607], Actual Value: 90.0
# Loss is 391.0929260253906
# Step: 14000 of 15630, Predicted value: [156.1393], Actual Value: 256.0
# Loss is 9972.16015625
# Step: 15000 of 15630, Predicted value: [90.595535], Actual Value: 88.0
# Loss is 6.7368035316467285
# -----------
# Epoch 15 of 30 error is 577.0221499412818
# -----------
# Step: 0 of 15630, Predicted value: [129.60654], Actual Value: 142.0
# Loss is 153.59793090820312
# Step: 1000 of 15630, Predicted value: [5.8783045], Actual Value: 4.0
# Loss is 3.5280277729034424
# Step: 2000 of 15630, Predicted value: [43.08667], Actual Value: 59.0
# Loss is 253.23406982421875
# Step: 3000 of 15630, Predicted value: [108.18009], Actual Value: 168.0
# Loss is 3578.42138671875
# Step: 4000 of 15630, Predicted value: [10.2181015], Actual Value: 9.0
# Loss is 1.4837713241577148
# Step: 5000 of 15630, Predicted value: [119.69667], Actual Value: 107.0
# Loss is 161.2054443359375
# Step: 6000 of 15630, Predicted value: [138.14226], Actual Value: 138.0
# Loss is 0.02023725025355816
# Step: 7000 of 15630, Predicted value: [103.808586], Actual Value: 96.0
# Loss is 60.97401809692383
# Step: 8000 of 15630, Predicted value: [86.888664], Actual Value: 87.0
# Loss is 0.012395650148391724
# Step: 9000 of 15630, Predicted value: [76.04682], Actual Value: 77.0
# Loss is 0.9085490703582764
# Step: 10000 of 15630, Predicted value: [159.38617], Actual Value: 82.0
# Loss is 5988.619140625
# Step: 11000 of 15630, Predicted value: [120.1876], Actual Value: 114.0
# Loss is 38.28638458251953
# Step: 12000 of 15630, Predicted value: [1.669714], Actual Value: 3.0
# Loss is 1.7696609497070312
# Step: 13000 of 15630, Predicted value: [123.279785], Actual Value: 90.0
# Loss is 1107.5440673828125
# Step: 14000 of 15630, Predicted value: [153.55081], Actual Value: 256.0
# Loss is 10495.8359375
# Step: 15000 of 15630, Predicted value: [89.759995], Actual Value: 88.0
# Loss is 3.097580671310425
# -----------
# Epoch 16 of 30 error is 784.2590931394752
# -----------
# Step: 0 of 15630, Predicted value: [136.44327], Actual Value: 142.0
# Loss is 30.87727165222168
# Step: 1000 of 15630, Predicted value: [10.588999], Actual Value: 4.0
# Loss is 43.4149055480957
# Step: 2000 of 15630, Predicted value: [60.681984], Actual Value: 59.0
# Loss is 2.8290700912475586
# Step: 3000 of 15630, Predicted value: [133.63033], Actual Value: 168.0
# Loss is 1181.2745361328125
# Step: 4000 of 15630, Predicted value: [11.938686], Actual Value: 9.0
# Loss is 8.63587760925293
# Step: 5000 of 15630, Predicted value: [106.283745], Actual Value: 107.0
# Loss is 0.5130214691162109
# Step: 6000 of 15630, Predicted value: [121.04213], Actual Value: 138.0
# Loss is 287.5693664550781
# Step: 7000 of 15630, Predicted value: [95.47922], Actual Value: 96.0
# Loss is 0.27121439576148987
# Step: 8000 of 15630, Predicted value: [92.585945], Actual Value: 87.0
# Loss is 31.202783584594727
# Step: 9000 of 15630, Predicted value: [74.16154], Actual Value: 77.0
# Loss is 8.05687141418457
# Step: 10000 of 15630, Predicted value: [80.16244], Actual Value: 82.0
# Loss is 3.376636266708374
# Step: 11000 of 15630, Predicted value: [115.20458], Actual Value: 114.0
# Loss is 1.4510183334350586
# Step: 12000 of 15630, Predicted value: [-10.671187], Actual Value: 3.0
# Loss is 186.9013671875
# Step: 13000 of 15630, Predicted value: [100.75058], Actual Value: 90.0
# Loss is 115.57496643066406
# Step: 14000 of 15630, Predicted value: [184.41898], Actual Value: 256.0
# Loss is 5123.84326171875
# Step: 15000 of 15630, Predicted value: [89.73383], Actual Value: 88.0
# Loss is 3.0061779022216797
# -----------
# Epoch 17 of 30 error is 629.632658226254
# -----------
# Step: 0 of 15630, Predicted value: [132.68066], Actual Value: 142.0
# Loss is 86.85002136230469
# Step: 1000 of 15630, Predicted value: [5.9750605], Actual Value: 4.0
# Loss is 3.9008638858795166
# Step: 2000 of 15630, Predicted value: [58.898804], Actual Value: 59.0
# Loss is 0.010240688920021057
# Step: 3000 of 15630, Predicted value: [113.66672], Actual Value: 168.0
# Loss is 2952.10546875
# Step: 4000 of 15630, Predicted value: [9.178154], Actual Value: 9.0
# Loss is 0.03173884376883507
# Step: 5000 of 15630, Predicted value: [109.971634], Actual Value: 107.0
# Loss is 8.830608367919922
# Step: 6000 of 15630, Predicted value: [129.26047], Actual Value: 138.0
# Loss is 76.37942504882812
# Step: 7000 of 15630, Predicted value: [98.92093], Actual Value: 96.0
# Loss is 8.53182601928711
# Step: 8000 of 15630, Predicted value: [84.8918], Actual Value: 87.0
# Loss is 4.444507598876953
# Step: 9000 of 15630, Predicted value: [86.53606], Actual Value: 77.0
# Loss is 90.93637084960938
# Step: 10000 of 15630, Predicted value: [79.60801], Actual Value: 82.0
# Loss is 5.721619129180908
# Step: 11000 of 15630, Predicted value: [111.27264], Actual Value: 114.0
# Loss is 7.438512325286865
# Step: 12000 of 15630, Predicted value: [2.109005], Actual Value: 3.0
# Loss is 0.7938721179962158
# Step: 13000 of 15630, Predicted value: [141.41177], Actual Value: 90.0
# Loss is 2643.17041015625
# Step: 14000 of 15630, Predicted value: [189.03455], Actual Value: 256.0
# Loss is 4484.3720703125
# Step: 15000 of 15630, Predicted value: [86.33488], Actual Value: 88.0
# Loss is 2.772634506225586
# -----------
# Epoch 18 of 30 error is 726.8712223704638
# -----------
# Step: 0 of 15630, Predicted value: [133.38947], Actual Value: 142.0
# Loss is 74.14130401611328
# Step: 1000 of 15630, Predicted value: [4.1210146], Actual Value: 4.0
# Loss is 0.014644532464444637
# Step: 2000 of 15630, Predicted value: [66.282585], Actual Value: 59.0
# Loss is 53.03604507446289
# Step: 3000 of 15630, Predicted value: [122.68039], Actual Value: 168.0
# Loss is 2053.8671875
# Step: 4000 of 15630, Predicted value: [9.169736], Actual Value: 9.0
# Loss is 0.028810279443860054
# Step: 5000 of 15630, Predicted value: [111.44163], Actual Value: 107.0
# Loss is 19.72805404663086
# Step: 6000 of 15630, Predicted value: [139.1667], Actual Value: 138.0
# Loss is 1.361194133758545
# Step: 7000 of 15630, Predicted value: [94.07079], Actual Value: 96.0
# Loss is 3.72183895111084
# Step: 8000 of 15630, Predicted value: [88.10267], Actual Value: 87.0
# Loss is 1.2158783674240112
# Step: 9000 of 15630, Predicted value: [75.26642], Actual Value: 77.0
# Loss is 3.005305051803589
# Step: 10000 of 15630, Predicted value: [83.20359], Actual Value: 82.0
# Loss is 1.4486298561096191
# Step: 11000 of 15630, Predicted value: [121.482216], Actual Value: 114.0
# Loss is 55.98355484008789
# Step: 12000 of 15630, Predicted value: [15.253756], Actual Value: 3.0
# Loss is 150.15452575683594
# Step: 13000 of 15630, Predicted value: [119.32339], Actual Value: 90.0
# Loss is 859.8610229492188
# Step: 14000 of 15630, Predicted value: [147.48883], Actual Value: 256.0
# Loss is 11774.673828125
# Step: 15000 of 15630, Predicted value: [92.36176], Actual Value: 88.0
# Loss is 19.02497673034668
# -----------
# Epoch 19 of 30 error is 786.1600632675081
# -----------
# Step: 0 of 15630, Predicted value: [134.58627], Actual Value: 142.0
# Loss is 54.96334457397461
# Step: 1000 of 15630, Predicted value: [4.635959], Actual Value: 4.0
# Loss is 0.40444403886795044
# Step: 2000 of 15630, Predicted value: [58.81069], Actual Value: 59.0
# Loss is 0.03583758324384689
# Step: 3000 of 15630, Predicted value: [120.45609], Actual Value: 168.0
# Loss is 2260.423095703125
# Step: 4000 of 15630, Predicted value: [9.3028755], Actual Value: 9.0
# Loss is 0.09173358231782913
# Step: 5000 of 15630, Predicted value: [132.80779], Actual Value: 107.0
# Loss is 666.041748046875
# Step: 6000 of 15630, Predicted value: [134.17949], Actual Value: 138.0
# Loss is 14.59630298614502
# Step: 7000 of 15630, Predicted value: [90.138855], Actual Value: 96.0
# Loss is 34.35301971435547
# Step: 8000 of 15630, Predicted value: [87.40471], Actual Value: 87.0
# Loss is 0.16378925740718842
# Step: 9000 of 15630, Predicted value: [77.376465], Actual Value: 77.0
# Loss is 0.14172577857971191
# Step: 10000 of 15630, Predicted value: [85.777794], Actual Value: 82.0
# Loss is 14.271726608276367
# Step: 11000 of 15630, Predicted value: [123.57945], Actual Value: 114.0
# Loss is 91.76590728759766
# Step: 12000 of 15630, Predicted value: [-0.25053215], Actual Value: 3.0
# Loss is 10.565958976745605
# Step: 13000 of 15630, Predicted value: [89.35137], Actual Value: 90.0
# Loss is 0.42071858048439026
# Step: 14000 of 15630, Predicted value: [167.67215], Actual Value: 256.0
# Loss is 7801.80908203125
# Step: 15000 of 15630, Predicted value: [84.372475], Actual Value: 88.0
# Loss is 13.158940315246582
# -----------
# Epoch 20 of 30 error is 818.5406104080347
# -----------
# Step: 0 of 15630, Predicted value: [138.92883], Actual Value: 142.0
# Loss is 9.432066917419434
# Step: 1000 of 15630, Predicted value: [4.724134], Actual Value: 4.0
# Loss is 0.524370014667511
# Step: 2000 of 15630, Predicted value: [66.881645], Actual Value: 59.0
# Loss is 62.120330810546875
# Step: 3000 of 15630, Predicted value: [121.628265], Actual Value: 168.0
# Loss is 2150.337890625
# Step: 4000 of 15630, Predicted value: [9.436795], Actual Value: 9.0
# Loss is 0.1907900720834732
# Step: 5000 of 15630, Predicted value: [122.284515], Actual Value: 107.0
# Loss is 233.6164093017578
# Step: 6000 of 15630, Predicted value: [124.62504], Actual Value: 138.0
# Loss is 178.8896026611328
# Step: 7000 of 15630, Predicted value: [91.51159], Actual Value: 96.0
# Loss is 20.145832061767578
# Step: 8000 of 15630, Predicted value: [90.47702], Actual Value: 87.0
# Loss is 12.089670181274414
# Step: 9000 of 15630, Predicted value: [76.38678], Actual Value: 77.0
# Loss is 0.3760390281677246
# Step: 10000 of 15630, Predicted value: [79.6096], Actual Value: 82.0
# Loss is 5.7140302658081055
# Step: 11000 of 15630, Predicted value: [114.266174], Actual Value: 114.0
# Loss is 0.07084876298904419
# Step: 12000 of 15630, Predicted value: [6.8192925], Actual Value: 3.0
# Loss is 14.586995124816895
# Step: 13000 of 15630, Predicted value: [108.57126], Actual Value: 90.0
# Loss is 344.8916320800781
# Step: 14000 of 15630, Predicted value: [136.28833], Actual Value: 256.0
# Loss is 14330.8837890625
# Step: 15000 of 15630, Predicted value: [95.89218], Actual Value: 88.0
# Loss is 62.28652572631836
# -----------
# Epoch 21 of 30 error is 846.9349767391213
# -----------
# Step: 0 of 15630, Predicted value: [125.644585], Actual Value: 142.0
# Loss is 267.4996032714844
# Step: 1000 of 15630, Predicted value: [16.420069], Actual Value: 4.0
# Loss is 154.2581024169922
# Step: 2000 of 15630, Predicted value: [50.049496], Actual Value: 59.0
# Loss is 80.11152648925781
# Step: 3000 of 15630, Predicted value: [129.51839], Actual Value: 168.0
# Loss is 1480.8345947265625
# Step: 4000 of 15630, Predicted value: [10.568507], Actual Value: 9.0
# Loss is 2.460214853286743
# Step: 5000 of 15630, Predicted value: [102.31749], Actual Value: 107.0
# Loss is 21.9259033203125
# Step: 6000 of 15630, Predicted value: [128.47765], Actual Value: 138.0
# Loss is 90.67522430419922
# Step: 7000 of 15630, Predicted value: [96.8769], Actual Value: 96.0
# Loss is 0.7689531445503235
# Step: 8000 of 15630, Predicted value: [90.29076], Actual Value: 87.0
# Loss is 10.829076766967773
# Step: 9000 of 15630, Predicted value: [69.49538], Actual Value: 77.0
# Loss is 56.319374084472656
# Step: 10000 of 15630, Predicted value: [90.356064], Actual Value: 82.0
# Loss is 69.82379913330078
# Step: 11000 of 15630, Predicted value: [129.79918], Actual Value: 114.0
# Loss is 249.6140594482422
# Step: 12000 of 15630, Predicted value: [2.3184547], Actual Value: 3.0
# Loss is 0.4645039439201355
# Step: 13000 of 15630, Predicted value: [149.56296], Actual Value: 90.0
# Loss is 3547.745849609375
# Step: 14000 of 15630, Predicted value: [140.35646], Actual Value: 256.0
# Loss is 13373.427734375
# Step: 15000 of 15630, Predicted value: [88.57606], Actual Value: 88.0
# Loss is 0.3318421542644501
# -----------
# Epoch 22 of 30 error is 859.0004116117141
# -----------
# Step: 0 of 15630, Predicted value: [126.65231], Actual Value: 142.0
# Loss is 235.55148315429688
# Step: 1000 of 15630, Predicted value: [4.52555], Actual Value: 4.0
# Loss is 0.2762026786804199
# Step: 2000 of 15630, Predicted value: [54.21132], Actual Value: 59.0
# Loss is 22.93146514892578
# Step: 3000 of 15630, Predicted value: [118.69753], Actual Value: 168.0
# Loss is 2430.7333984375
# Step: 4000 of 15630, Predicted value: [10.811663], Actual Value: 9.0
# Loss is 3.2821216583251953
# Step: 5000 of 15630, Predicted value: [107.37487], Actual Value: 107.0
# Loss is 0.14052774012088776
# Step: 6000 of 15630, Predicted value: [146.47734], Actual Value: 138.0
# Loss is 71.86530303955078
# Step: 7000 of 15630, Predicted value: [94.174446], Actual Value: 96.0
# Loss is 3.3326470851898193
# Step: 8000 of 15630, Predicted value: [88.55352], Actual Value: 87.0
# Loss is 2.4134249687194824
# Step: 9000 of 15630, Predicted value: [77.658295], Actual Value: 77.0
# Loss is 0.43335187435150146
# Step: 10000 of 15630, Predicted value: [88.92563], Actual Value: 82.0
# Loss is 47.964332580566406
# Step: 11000 of 15630, Predicted value: [117.62165], Actual Value: 114.0
# Loss is 13.116353988647461
# Step: 12000 of 15630, Predicted value: [6.899781], Actual Value: 3.0
# Loss is 15.208293914794922
# Step: 13000 of 15630, Predicted value: [85.92009], Actual Value: 90.0
# Loss is 16.645668029785156
# Step: 14000 of 15630, Predicted value: [155.42932], Actual Value: 256.0
# Loss is 10114.4609375
# Step: 15000 of 15630, Predicted value: [101.98706], Actual Value: 88.0
# Loss is 195.6378631591797
# -----------
# Epoch 23 of 30 error is 795.5293091112214
# -----------
# Step: 0 of 15630, Predicted value: [137.14104], Actual Value: 142.0
# Loss is 23.609521865844727
# Step: 1000 of 15630, Predicted value: [5.3587494], Actual Value: 4.0
# Loss is 1.846199870109558
# Step: 2000 of 15630, Predicted value: [63.075817], Actual Value: 59.0
# Loss is 16.612285614013672
# Step: 3000 of 15630, Predicted value: [105.40412], Actual Value: 168.0
# Loss is 3918.243896484375
# Step: 4000 of 15630, Predicted value: [10.745747], Actual Value: 9.0
# Loss is 3.04763126373291
# Step: 5000 of 15630, Predicted value: [123.369774], Actual Value: 107.0
# Loss is 267.969482421875
# Step: 6000 of 15630, Predicted value: [132.29999], Actual Value: 138.0
# Loss is 32.49013900756836
# Step: 7000 of 15630, Predicted value: [97.46947], Actual Value: 96.0
# Loss is 2.1593337059020996
# Step: 8000 of 15630, Predicted value: [88.52262], Actual Value: 87.0
# Loss is 2.3183751106262207
# Step: 9000 of 15630, Predicted value: [74.16642], Actual Value: 77.0
# Loss is 8.029175758361816
# Step: 10000 of 15630, Predicted value: [82.00341], Actual Value: 82.0
# Loss is 1.163041451945901e-05
# Step: 11000 of 15630, Predicted value: [109.06683], Actual Value: 114.0
# Loss is 24.336132049560547
# Step: 12000 of 15630, Predicted value: [3.4981966], Actual Value: 3.0
# Loss is 0.24819985032081604
# Step: 13000 of 15630, Predicted value: [113.90761], Actual Value: 90.0
# Loss is 571.57373046875
# Step: 14000 of 15630, Predicted value: [116.2409], Actual Value: 256.0
# Loss is 19532.603515625
# Step: 15000 of 15630, Predicted value: [87.01907], Actual Value: 88.0
# Loss is 0.962216854095459
# -----------
# Epoch 24 of 30 error is 1150.5388205896047
# -----------
# Step: 0 of 15630, Predicted value: [120.05661], Actual Value: 142.0
# Loss is 481.5123596191406
# Step: 1000 of 15630, Predicted value: [4.0012865], Actual Value: 4.0
# Loss is 1.6550993677810766e-06
# Step: 2000 of 15630, Predicted value: [55.98446], Actual Value: 59.0
# Loss is 9.093487739562988
# Step: 3000 of 15630, Predicted value: [133.25014], Actual Value: 168.0
# Loss is 1207.552978515625
# Step: 4000 of 15630, Predicted value: [9.211888], Actual Value: 9.0
# Loss is 0.04489665850996971
# Step: 5000 of 15630, Predicted value: [106.850136], Actual Value: 107.0
# Loss is 0.022459277883172035
# Step: 6000 of 15630, Predicted value: [137.8932], Actual Value: 138.0
# Loss is 0.011405441910028458
# Step: 7000 of 15630, Predicted value: [91.51941], Actual Value: 96.0
# Loss is 20.075695037841797
# Step: 8000 of 15630, Predicted value: [90.58411], Actual Value: 87.0
# Loss is 12.845819473266602
# Step: 9000 of 15630, Predicted value: [77.8205], Actual Value: 77.0
# Loss is 0.6732255816459656
# Step: 10000 of 15630, Predicted value: [85.21313], Actual Value: 82.0
# Loss is 10.324186325073242
# Step: 11000 of 15630, Predicted value: [122.628235], Actual Value: 114.0
# Loss is 74.4464340209961
# Step: 12000 of 15630, Predicted value: [4.7738695], Actual Value: 3.0
# Loss is 3.146613121032715
# Step: 13000 of 15630, Predicted value: [160.97218], Actual Value: 90.0
# Loss is 5037.05078125
# Step: 14000 of 15630, Predicted value: [167.16508], Actual Value: 256.0
# Loss is 7891.64208984375
# Step: 15000 of 15630, Predicted value: [88.81254], Actual Value: 88.0
# Loss is 0.6602182388305664
# -----------
# Epoch 25 of 30 error is 797.82743360919
# -----------
# Step: 0 of 15630, Predicted value: [142.26862], Actual Value: 142.0
# Loss is 0.07215440273284912
# Step: 1000 of 15630, Predicted value: [4.6191745], Actual Value: 4.0
# Loss is 0.3833770453929901
# Step: 2000 of 15630, Predicted value: [60.742695], Actual Value: 59.0
# Loss is 3.036985397338867
# Step: 3000 of 15630, Predicted value: [111.6532], Actual Value: 168.0
# Loss is 3174.962158203125
# Step: 4000 of 15630, Predicted value: [12.700648], Actual Value: 9.0
# Loss is 13.69479751586914
# Step: 5000 of 15630, Predicted value: [117.44769], Actual Value: 107.0
# Loss is 109.15428924560547
# Step: 6000 of 15630, Predicted value: [129.97847], Actual Value: 138.0
# Loss is 64.3449478149414
# Step: 7000 of 15630, Predicted value: [99.01206], Actual Value: 96.0
# Loss is 9.072518348693848
# Step: 8000 of 15630, Predicted value: [90.11391], Actual Value: 87.0
# Loss is 9.696415901184082
# Step: 9000 of 15630, Predicted value: [64.30638], Actual Value: 77.0
# Loss is 161.12796020507812
# Step: 10000 of 15630, Predicted value: [87.730835], Actual Value: 82.0
# Loss is 32.84246826171875
# Step: 11000 of 15630, Predicted value: [118.69334], Actual Value: 114.0
# Loss is 22.027406692504883
# Step: 12000 of 15630, Predicted value: [3.5458975], Actual Value: 3.0
# Loss is 0.29800406098365784
# Step: 13000 of 15630, Predicted value: [165.76746], Actual Value: 90.0
# Loss is 5740.70751953125
# Step: 14000 of 15630, Predicted value: [101.09482], Actual Value: 256.0
# Loss is 23995.615234375
# Step: 15000 of 15630, Predicted value: [92.92266], Actual Value: 88.0
# Loss is 24.232589721679688
# -----------
# Epoch 26 of 30 error is 963.765701687591
# -----------
# Step: 0 of 15630, Predicted value: [120.291115], Actual Value: 142.0
# Loss is 471.27569580078125
# Step: 1000 of 15630, Predicted value: [7.558997], Actual Value: 4.0
# Loss is 12.666460990905762
# Step: 2000 of 15630, Predicted value: [50.716225], Actual Value: 59.0
# Loss is 68.62093353271484
# Step: 3000 of 15630, Predicted value: [134.80185], Actual Value: 168.0
# Loss is 1102.1171875
# Step: 4000 of 15630, Predicted value: [8.09251], Actual Value: 9.0
# Loss is 0.8235377073287964
# Step: 5000 of 15630, Predicted value: [121.0597], Actual Value: 107.0
# Loss is 197.6751708984375
# Step: 6000 of 15630, Predicted value: [116.07948], Actual Value: 138.0
# Loss is 480.5090637207031
# Step: 7000 of 15630, Predicted value: [93.26836], Actual Value: 96.0
# Loss is 7.461877346038818
# Step: 8000 of 15630, Predicted value: [86.22859], Actual Value: 87.0
# Loss is 0.5950704216957092
# Step: 9000 of 15630, Predicted value: [70.39644], Actual Value: 77.0
# Loss is 43.60702133178711
# Step: 10000 of 15630, Predicted value: [81.504845], Actual Value: 82.0
# Loss is 0.24517880380153656
# Step: 11000 of 15630, Predicted value: [133.78432], Actual Value: 114.0
# Loss is 391.419189453125
# Step: 12000 of 15630, Predicted value: [1.890995], Actual Value: 3.0
# Loss is 1.2298920154571533
# Step: 13000 of 15630, Predicted value: [147.00659], Actual Value: 90.0
# Loss is 3249.75146484375
# Step: 14000 of 15630, Predicted value: [144.64221], Actual Value: 256.0
# Loss is 12400.556640625
# Step: 15000 of 15630, Predicted value: [93.0154], Actual Value: 88.0
# Loss is 25.154273986816406
# -----------
# Epoch 27 of 30 error is 1005.5063866228722
# -----------
# Step: 0 of 15630, Predicted value: [112.68232], Actual Value: 142.0
# Loss is 859.5263671875
# Step: 1000 of 15630, Predicted value: [5.526705], Actual Value: 4.0
# Loss is 2.330827474594116
# Step: 2000 of 15630, Predicted value: [61.561157], Actual Value: 59.0
# Loss is 6.559526443481445
# Step: 3000 of 15630, Predicted value: [142.51582], Actual Value: 168.0
# Loss is 649.4432373046875
# Step: 4000 of 15630, Predicted value: [9.842041], Actual Value: 9.0
# Loss is 0.7090330719947815
# Step: 5000 of 15630, Predicted value: [104.695015], Actual Value: 107.0
# Loss is 5.312955856323242
# Step: 6000 of 15630, Predicted value: [132.05606], Actual Value: 138.0
# Loss is 35.330413818359375
# Step: 7000 of 15630, Predicted value: [95.42573], Actual Value: 96.0
# Loss is 0.3297885060310364
# Step: 8000 of 15630, Predicted value: [86.06198], Actual Value: 87.0
# Loss is 0.8798792958259583
# Step: 9000 of 15630, Predicted value: [75.407555], Actual Value: 77.0
# Loss is 2.5358822345733643
# Step: 10000 of 15630, Predicted value: [84.10677], Actual Value: 82.0
# Loss is 4.4384942054748535
# Step: 11000 of 15630, Predicted value: [110.62251], Actual Value: 114.0
# Loss is 11.407419204711914
# Step: 12000 of 15630, Predicted value: [-1.688652], Actual Value: 3.0
# Loss is 21.983457565307617
# Step: 13000 of 15630, Predicted value: [144.21513], Actual Value: 90.0
# Loss is 2939.28076171875
# Step: 14000 of 15630, Predicted value: [146.46094], Actual Value: 256.0
# Loss is 11998.806640625
# Step: 15000 of 15630, Predicted value: [89.00415], Actual Value: 88.0
# Loss is 1.0083179473876953
# -----------
# Epoch 28 of 30 error is 872.1930348039617
# -----------
# Step: 0 of 15630, Predicted value: [129.90413], Actual Value: 142.0
# Loss is 146.31008911132812
# Step: 1000 of 15630, Predicted value: [4.3872147], Actual Value: 4.0
# Loss is 0.14993520081043243
# Step: 2000 of 15630, Predicted value: [58.111614], Actual Value: 59.0
# Loss is 0.7892292737960815
# Step: 3000 of 15630, Predicted value: [141.854], Actual Value: 168.0
# Loss is 683.6130981445312
# Step: 4000 of 15630, Predicted value: [10.721397], Actual Value: 9.0
# Loss is 2.9632089138031006
# Step: 5000 of 15630, Predicted value: [103.91922], Actual Value: 107.0
# Loss is 9.491205215454102
# Step: 6000 of 15630, Predicted value: [128.00034], Actual Value: 138.0
# Loss is 99.9932861328125
# Step: 7000 of 15630, Predicted value: [97.06176], Actual Value: 96.0
# Loss is 1.1273342370986938
# Step: 8000 of 15630, Predicted value: [84.31525], Actual Value: 87.0
# Loss is 7.2079010009765625
# Step: 9000 of 15630, Predicted value: [77.422516], Actual Value: 77.0
# Loss is 0.17851966619491577
# Step: 10000 of 15630, Predicted value: [82.60781], Actual Value: 82.0
# Loss is 0.3694341778755188
# Step: 11000 of 15630, Predicted value: [101.76938], Actual Value: 114.0
# Loss is 149.58810424804688
# Step: 12000 of 15630, Predicted value: [-0.8804016], Actual Value: 3.0
# Loss is 15.057517051696777
# Step: 13000 of 15630, Predicted value: [115.33305], Actual Value: 90.0
# Loss is 641.7636108398438
# Step: 14000 of 15630, Predicted value: [133.82237], Actual Value: 256.0
# Loss is 14927.373046875
# Step: 15000 of 15630, Predicted value: [96.19837], Actual Value: 88.0
# Loss is 67.21330261230469
# -----------
# Epoch 29 of 30 error is 863.1719377588547
# -----------

# %%
epocherror = []

for i in range(num_epochs):
  epocherror.append(sum(kfold_singleloss_list[i])/len(kfold_singleloss_list[i]))

x = range(num_epochs)
plt.plot(x,epocherror)

# %% [markdown]
# ## Test

# %%
# initialize testing lists
testdata_list = []
alltestunitdata_list = []
alltestunitdata_scaled_list = []
testfailurecycle_list = []
unit_list = []
rul_list = []

# run through each of the 4 testing files
for i in range(files):
    
    # read in testing data, one file at a time
    test = pd.read_csv(test_data[i],delimiter=' ',header=None)
    rul = pd.read_csv(rul_data[i],delimiter=' ',header=None)
    
    # drop NA in RUL data
    rul.dropna(axis=1,how='all',inplace=True)
    
    # initialize starting index for each unit collection
    startindex = 0
    
    # initialize list of unit data, this will seperate out each file into a 
    # seperate entry in a list
    unitdata_list = []
    
    unitnumber = 0
    
    # run through an individual testing file to pull out groups of unit data
    for k in range(len(test)-1):
        
        # check the unit number of the next line, if they are different then 
        # this k value represents the end of a grouping of units
        if test.iloc[k,0] != test.iloc[k+1,0]:
            # the last index in the unit group
            endindex = k
            
            # all of the data in the unit group, as defined by the start and
            # end index values
            unitdata = test.iloc[startindex:endindex,:]
            # drop columns with NA values
            unitdata.dropna(axis=1,how='all',inplace=True)
            # add unit number to list before dropping
            unit_list.append(unitdata.iloc[0,0])            
            # drop unit number as it isn't relevant to predictions
            unitdata = unitdata.iloc[:,1:]
            # drop uncorrelated columns
            unitdata.drop(unitdata.columns[[3,4,8,13,19,21,22]],axis=1,inplace=True)

            # scale values
            unitdata_cycles = unitdata.iloc[:,0].to_numpy()
            unitdata_scaled = input_scale.fit_transform(unitdata.iloc[:,1:])
            unitdata_scaled = np.column_stack((unitdata_cycles,unitdata_scaled))

            # in the testing data, we assume it failed during the last cycle
            failurecycle = rul.iloc[unitnumber] + unitdata_cycles[-1]
            rul_list.append(rul.iloc[unitnumber].to_numpy())
            
            # update the starting index to the next unit group
            startindex = endindex + 1
            
            # append to lists
            testfailurecycle_list.append(failurecycle.values)
            unitdata_list.append(unitdata)
            alltestunitdata_list.append(unitdata)
            alltestunitdata_scaled_list.append(unitdata_scaled)
            
            unitnumber += 1
            
        # collecting the last unit of the dataset    
        elif k == len(test)-2:
            # the last index in the unit group
            endindex = k
            
            # all of the data in the unit group, as defined by the start and
            # end index values
            unitdata = test.iloc[startindex:endindex,:]
            # drop columns with NA values
            unitdata.dropna(axis=1,how='all',inplace=True)
            # add unit number to list before dropping
            unit_list.append(unitdata.iloc[0,0]) 
            # drop unit number as it isn't relevant to predictions
            unitdata = unitdata.iloc[:,1:]
            # drop uncorrelated columns
            unitdata.drop(unitdata.columns[[3,4,8,13,19,21,22]],axis=1,inplace=True)
            
            # scale values
            unitdata_cycles = unitdata.iloc[:,0].to_numpy()
            unitdata_scaled = input_scale.fit_transform(unitdata.iloc[:,1:])
            unitdata_scaled = np.column_stack((unitdata_cycles,unitdata_scaled))
            # in the testing data, we assume it failed during the last cycle
            failurecycle = rul.iloc[unitnumber] + unitdata_cycles[-1]
            rul_list.append(rul.iloc[unitnumber].to_numpy())
            
            # update the starting index to the next unit group
            startindex = endindex + 1
            
            # append to lists
            testfailurecycle_list.append(failurecycle.values)
            unitdata_list.append(unitdata)
            alltestunitdata_list.append(unitdata)
            alltestunitdata_scaled_list.append(unitdata_scaled)
            
            unitnumber += 1
            
            
            
    # append to list where each item is for a different file
    testdata_list.append(unitdata_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:78: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
datapoints = 50

groupedtestData_list = []
test_predict_list = []
predictions_list = []
removeindex = []

for i in range(len(alltestunitdata_scaled_list)):
    if len(alltestunitdata_scaled_list[i]) < datapoints:
        print(i)
        removeindex.append(i)

for k in range(len(removeindex)):
    removerow = removeindex[len(removeindex)-(k+1)]
    del alltestunitdata_scaled_list[removerow]
    del testfailurecycle_list[removerow]
    del unit_list[removerow]
    del rul_list[removerow]


for j in range(len(alltestunitdata_scaled_list)):
    # pull out a single dataset from the training data
    dataset = alltestunitdata_scaled_list[j]
    # pull out the number of cycles for failure of that training dataset
    failurecycle = testfailurecycle_list[j]
    
    predictions = []
    # for each set of trainin data, group the data into datapoint number of rows
    # and attach the failure cycle to end
    for i in range(len(dataset)-datapoints+1):
        # RUL calculation
        RULentry = failurecycle - (i+datapoints)
        # select number of datapoints from training data
        groupedDataset = dataset[i:(i+datapoints),:]
        # make a list of the grouped data and the failures to cycle it should predict
        groupedData_entry = [groupedDataset,RULentry]
        # put all the data into a list
        groupedtestData_list.append(groupedData_entry)
        
        test_tensor = torch.tensor(groupedDataset).float()

        test_predict = model(test_tensor.cuda())

        predictions.append(test_predict.detach().cpu().numpy())
    
    test_singleprediction = predictions[-1]
    test_predict_list.append(test_singleprediction)
    predictions_list.append(predictions)

    # print('Prediction: {}, RUL: {}'.format(test_singleprediction,failurecycle))
# Out:
# 0
# 1
# 13
# 21
# 24
# 32
# 38
# 84

# %%
trainingunit_np = np.array(trainingunit_list)
trainfailurecycle_np = np.array(trainfailurecycle_list)
unit_np = np.array(unit_list)
testfailurecycle_np = np.array(testfailurecycle_list)

plt.figure()
plt.scatter(trainingunit_np,trainfailurecycle_np)
plt.scatter(unit_np,testfailurecycle_np)
plt.ylabel('Cycles at failure')
plt.xlabel('Unit Number')
plt.title('Training vs. Test Set Cyles at Failure')
plt.legend(('Training','Test'))

# %%
step_np = range(len(test_predict_list))
test_predict_np = np.array(test_predict_list)
testfailurecycle_np = np.array(testfailurecycle_list)
RUL_np = np.array(rul_list)

plt.figure()
plt.scatter(step_np,test_predict_np)
plt.scatter(step_np,RUL_np)
plt.ylabel('Remaining Useful Life [cycles]',size=14)
plt.xlabel('Steps',size=14)
plt.legend(('Prediction','Actual'))
plt.rcParams["figure.figsize"] = (10,6)

# %%
unit_np = np.array(unit_list)
test_predict_np = np.array(test_predict_list)
testfailurecycle_np = np.array(testfailurecycle_list)
RUL_np = np.array(rul_list)

plt.figure()
plt.scatter(unit_np,test_predict_np)
plt.scatter(unit_np,RUL_np)
plt.ylabel('Remaining Useful Life [cycles]',size=14)
plt.xlabel('Unit Number',size=14)
plt.legend(('Prediction','Actual'))
